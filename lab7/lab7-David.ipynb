# %% [markdown]
# # Wide and Deep Neural Network

# %% [markdown]
# ### Introduction to Our Problem
# There are literally tens of thousands of movies out there today. While some do great at the box office and bring in a lot of money, others flop making only a fraction compared to the top hits. What if we had a scientific way of accurately predicting how much revenue a movie would generate over its lifetime? Well, through machine learning we believe that we actually can!
#
# The dataset we are using is found on <a href="https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset">Kaggle</a>. It consists of 5000+ movies scraped from the review site IMDB. There is quite a bit of data recorded for each movie and so we had a lot to work with to try to predict the next big hit. The data was collected from web scraping IMDB using a python library called "scrappy" to collect all of the data below. The features recorded for each movie are:
#
# Basic Info:
# - movie title
# - color (black and white or color)
# - duration of the movie
# - director name
# - gross (total revenue)
# - genres (a lits of different genres ascribed to the movie)
# - number of faces in movie poster
# - language of the movie
# - country the movie was produced in
# - content rating (G, PG, PG-13, R, NC-17)
# - budget
# - year of release
# - aspect ratio
# - name of the 3rd actor
# - name of the 2nd actor
# - name of the 1st actor
#
# Facebook Info:
# - number of director facebook likes
# - number of facebook likes for the whole cast
# - number of the movie's facebook likes
# - number of the 3rd actor's facebook likes
# - number of the 2nd actor's facebook likes
# - number of the 1st actor's facebook likes
#
# IMDB Specific Info:
# - number of imdb users who rated the movie
# - number of critical reviews for the movie
# - number of users who left a review
# - imdb score
# - top plot keywords
#
#
# With all of this data collected on so many movies, we hope to be able to use this to build out a multi-layer perceptron  to accurately predict the financial success (measured in categories of gross revenue: low, low-mid, high-mid, and high) of a movie. We think that this could be a useful tool to anyone in the movie industry who is concerned with making a profit on their movie. It could also help a producer understand which of these features are the most important to an accurate prediction, what content rating is most important, how budget affects outcome, etc.
#
#
# We believe that the algorithm would have to predict with a relatively low cost (under ~30) to be found useful by movie directors, producers, etc.

# %% [markdown]
# ### Data Pre-processing:
# We made a number of changes to both the original csv obtained from kaggle before we loaded it and to the data once it was loaded in.
#
#
# Pre-processing of the CSV:
# - We first removed the imdb link from the csv because we knew we would never need to use that (**Note: this was the only feature removed from the csv**)
# - We then went through and deleted all of the movies that were made in another country (foriegn films) we did this because we wanted to just look at American films, also because the currency units for those countries (for budget and gross) were in native currency units, not USD, and with changing exchange rates, it's not very easy to compare across countries.
# - We then went through and converted all 0 values for gross, movie_facebook_likes, and director_facebook_likes to a blank value in the csv (so that it is read in as NaN by pandas), this is so that we cna more easily impute values later. Note: according to the description on the kaggle entry, because of the way the data was scraped, some movies had missing data. The Python scraper just made these values into a 0 instead of NaN.
# - We then removed all movies with an undefined gross. Being the feature we are trying to predict, we should not be imputing values for gross to train our model. That will basically reduce our model to an imputation algorithm...
# - We then removed all movies that were made before 1935. We did this because there were only a handful of movies ranging from 1915 to 1935, the way we are classifying budget (described below) would not work with a small sample of movies from that time period. We could have cut this number at a different year (say 1960), but we didn't want to exclude such classics as "Bambi" or "Gone With the Wind"
# - Lastly, we had to adjust the gross revenue and budget values for inflation, since the movies spanned many years. For adjusting for inflation we obtained a csv of consumer price index (CPI) for every month since 1947. To simplify, we just took the value for January of that year to use for the whole year. We then took the CPI and calculated the ratio per year compared to 2017 dollars. We then took the budget and gross and multiplied them out with their appropriate ratio value. We then exported this to the csv that we use for the rest of this lab. **NB:** This was done outside of this notebook because this whole process took a very long time when it was included in the notebook when done every time.

# %% [markdown]
# Pre-processing of the Data:
# - After the above steps, we made more edits to the data using pandas. First, we removed features that we thought would be un-useful to our prediction algorithm. We removed all features concerning facebook likes. We did this because a significant portion of the movies in the training set debuted before facebook was invented and widely adopted. While some of these movies have received retroactive "likes" on facebook, only the most famous classics received a substantial amount of retraoctive "likes". Most lesser known films received very low amounts of "likes" (presumably because modern movie watchers don't really care to search for lesser known movies on facebook, or because the movie doesn't have a facebook). For this reason we decided to remove movie_facebook_likes
# - Likewise, we removed the other "likes" for the same reasons as above. For example, the esteemed director George Lucas has a total of 0 "likes" between all of his films. This feature obviously would not help us predict the profitability of movies.
# - We also removed irrelevant information such as aspect_ratio, language, and country. Because we deleted all foreign films the country will always be USA. A simple filter of the data reveals that there are no more than 20 movies made in the US that use a language other than English, therefore there is not enough data to use language as training feature. However, we did not delete the movies in a different language, because most of them were famous films such as *Letters from Iwo Jima* and *The Kite Runner*. We still count them as a valuable part of the dataset, just don't find the language of particular value. Lastly, we removed aspect_ratio because that seems to be unimportant for predicting the success of a movie.
# - Lastly, we removed other features that would be difficult to use in our machine learning model such as actor names and plot keywords. We initially tried to include these in our model using one-hot encoding, but the resultant array was so enormous that the model would take a very, very long time to train.

# %%
# Take the dataframe and adjust for inflation and then use the df_to_csv function to export to csv 
# and then export to csv and then delete code

import pandas as pd
import numpy as np
df = pd.read_csv("inflation_corrected_dataset.csv")
for x in ['movie_facebook_likes', 'director_facebook_likes', 'actor_2_facebook_likes', 
          'actor_1_facebook_likes','actor_3_facebook_likes', 'cast_total_facebook_likes',
          'aspect_ratio', 'language', 'country', 'plot_keywords', 'actor_3_name', 'actor_2_name', 'movie_title', 'genres', 'color']:
    if x in df:
        del df[x]
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3222 entries, 0 to 3221
# Data columns (total 12 columns):
# director_name             3222 non-null object
# num_critic_for_reviews    3219 non-null float64
# duration                  3221 non-null float64
# gross                     3222 non-null int64
# actor_1_name              3220 non-null object
# num_voted_users           3222 non-null int64
# facenumber_in_poster      3216 non-null float64
# num_user_for_reviews      3221 non-null float64
# content_rating            3196 non-null object
# budget                    3062 non-null float64
# title_year                3222 non-null int64
# imdb_score                3222 non-null float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 302.1+ KB
# None

# %% [markdown]
# Below we group the columns by director_name and then impute as many values as we can, dropping the rows where we can't impute.

# %%
# Tamper with the groupings to improve imputations? How do we improve how many values get imputed?
df_grouped = df.groupby(by=['director_name'])
# director_name adds about 50 rows (imputes about 50 rows and then deletes about 100)

# %%
df_imputed = df_grouped.transform(lambda grp: grp.fillna(grp.median()))
col_deleted = list( set(df.columns) - set(df_imputed.columns)) #in case the median op deleted columns
df_imputed[col_deleted] = df[col_deleted]

# drop rows that still have missing values after imputation
df_imputed.dropna(inplace=True)
print(df_imputed.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3127 entries, 0 to 3220
# Data columns (total 12 columns):
# num_critic_for_reviews    3127 non-null float64
# duration                  3127 non-null float64
# gross                     3127 non-null int64
# num_voted_users           3127 non-null int64
# facenumber_in_poster      3127 non-null float64
# num_user_for_reviews      3127 non-null float64
# budget                    3127 non-null float64
# title_year                3127 non-null int64
# imdb_score                3127 non-null float64
# content_rating            3127 non-null object
# actor_1_name              3127 non-null object
# director_name             3127 non-null object
# dtypes: float64(6), int64(3), object(3)
# memory usage: 317.6+ KB
# None

# %% [markdown]
# ### Scaling the Data
# Below we scale the data using the methods shown so as to not adversely affect the gamma value. We scaled down all of the numerical values to be within -1 and 1. We also one-hot encode the content rating. We forego encoding the director name or actor names because they proved to make our matrix way too large to run computations on.

# %%
# %%time
#scaling budgets!
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_rows', 200)

budget = df_imputed['budget'].values.reshape(-1, 1)
df_imputed.reset_index(drop=True, inplace=True)
print("df: ",df_imputed.shape)

append_list = [df_imputed]

df = pd.concat(append_list, axis=1)

print(df.shape)
# Out:
# df:  (3127, 12)
# (3127, 12)
# Wall time: 264 ms

# %% [markdown]
# ### Cutting the gross into categories
# Below we cut the adjusted, scaled, gross into 4 main categories: low, low-mid, high-mid, and high. We did this because otherwise the model would not be able to produce raw gross accurately. We also used the "qcut" function to evenly distribute the classes among the classifications, because when we did a normal cut method most of the classes would fall in the lowest category and throw off our predictions.

# %%
from sklearn.preprocessing import LabelEncoder

spacing = np.linspace(0, max(df['gross']), 100)
labels = []

labels = ["low", "low-mid", "high-mid", "high"]
df['gross_group'] = pd.qcut(df['gross'], 4, labels=labels)

df = df.drop('gross', axis=1)

# %% [markdown]
# ## Evaluation
# ### Choosing Evaluation Metrics

# %% [markdown]
# For our dataset, accuracy is not the best evaluation metric, because that does not account properly for false positives. False positives for our business case are MUCH worse than a false negative. It would be very bad to predict that a movie will gross high, when in fact it grosses lowly. However, if we predict the movie will gross low, and it ends up grossing highly, that isn't as bad, because the director will either be pleasantly surprised, or he will choose to not undertake the filming in the first place. It is better to not film and miss out on the potential money, than to undertake the film thinking that it would be lucrative, when in fact it is not.
#
# Because we are using a multi-class classification model we can not simply use precision, recall, or f1 score, but must construct a cost matrix with different weights that correspond to the different combination of predictions and results. Below we have our cost matrix defined. As you can see we weight a false positive with a 20 and a false negative with a 6. We give them this much of a cost difference because of the aforementioned reasons about false positives. Any True predictions are a negative one, and the other numbers in the matrix are scaled appropriately dependent upon how bad they would be as a result.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc, accuracy_score

cost_matrix = np.array([-1,10, 14,20,2,-1,10,14,4,2,-1,10,6,4,2,-1]) #give a reason for why these numbers chosen
cost_matrix = cost_matrix.reshape(4,4)
print(cost_matrix)
# Out:
# [[-1 10 14 20]
#  [ 2 -1 10 14]
#  [ 4  2 -1 10]
#  [ 6  4  2 -1]]

# %% [markdown]
# ### Dividing up training/testing data, Scaling

# %% [markdown]
# For our dataset we want to use Stratified 10-fold cross validation because it is the best and works for our dataset well. Below we create the StratifiedKFold object and then use it many times later on in the lab. We selected this method instead of a simple 80/20 split because we new that we wanted to test on multiple randomized sets of data, instead of just the same one, so as to avoid data snooping and improper parameter tuning. We chose not to use the shuffle option becuase we wanted to compare our custom implementation to a standard MLP using the same indices for training and testing data. Below we also drop a few more fields that we no longer need due to categorizing the gross. We also remove a few categorical fields, run all of the continuous features through the standard scaler, and append the categorical features back on. At the end, X is an ndarray of values.

# %%
df
# Out:
#       num_critic_for_reviews  duration  num_voted_users  facenumber_in_poster  \
# 0                       90.0      92.0            19236                   1.0
# 1                       41.0     102.0             3258                   0.0
# 2                       21.0     107.0             3167                   0.0
# 3                       44.0     152.0             9456                   0.0
# 4                       42.0     135.0             6359                   1.0
# 5                       67.0      80.0             4812                   0.0
# 6                      134.0     108.0           100890                   2.0
# 7                      181.0     120.0           175196                   2.0
# 8                      290.0     108.0           422432                   2.0
# 9                      120.0     152.0            71919                   0.0
# 10                      61.0     197.0            29323                   0.0
# 11                      82.0     170.0            66959                   1.0
# 12                     145.0     139.0           107408                   2.0
# 13                      24.0      95.0              891                   1.0
# 14                      27.0     225.0             6484                   6.0
# 15                      89.0     200.0            55816                   2.0
# 16                     119.0     174.0           148172                   3.0
# 17                      53.0     152.0             5294                   2.0
# 18                     130.0     110.0           152089                   1.0
# 19                      22.0     143.0             1547                   2.0
# 20                     101.0     109.0             7584                   8.0
# 21                      53.0     215.0            12631                   0.0
# 22                      66.0     181.0            29839                   0.0
# 23                      38.0      97.0             3340                   1.0
# 24                       8.0      65.0              803                   1.0
# 25                     208.0     175.0          1155770                   1.0
# 26                      73.0     108.0            16792                   2.0
# 27                     304.0     132.0           284252                   0.0
# 28                     119.0     129.0           175607                   0.0
# 29                     100.0     112.0            63839                   1.0
# 30                     112.0     112.0            67797                   0.0
# 31                     149.0     220.0           790926                   1.0
# 32                     129.0     106.0           112671                   0.0
# 33                     121.0      93.0            95294                   0.0
# 34                       5.0      86.0             3411                   0.0
# 35                     277.0      88.0            96410                   0.0
# 36                     277.0      88.0            96411                   0.0
# 37                     385.0     130.0           412454                   0.0
# 38                     149.0     133.0           680041                   0.0
# 39                     112.0     119.0            39847                   1.0
# 40                     141.0     145.0           375240                   0.0
# 41                      56.0     175.0            40277                  14.0
# 42                     171.0     135.0           139288                   0.0
# 43                     282.0     125.0           911097                   1.0
# 44                     154.0      93.0           192940                   0.0
# 45                      95.0      97.0             3274                   0.0
# 46                     169.0     188.0           126357                   0.0
# 47                      32.0     118.0            10895                   0.0
# 48                      75.0     131.0            51314                   0.0
# 49                     124.0     110.0           170027                   2.0
# 50                      94.0     109.0            90177                   6.0
# 51                     318.0     101.0           157857                   0.0
# 52                     318.0     101.0           157857                   0.0
# 53                     318.0     101.0           157863                   0.0
# 54                      71.0     117.0            12611                   0.0
# 55                     134.0     143.0            63330                   2.0
# 56                     261.0     289.0           450676                   1.0
# 57                      32.0     125.0             6142                   0.0
# 58                      53.0     112.0            87090                   0.0
# 59                     121.0     116.0            76331                   4.0
# 60                     102.0     325.0             9830                   0.0
# 61                     125.0     148.0           142448                   1.0
# 62                      26.0     124.0             2998                   0.0
# 63                     223.0     127.0           837759                   0.0
# 64                     151.0     121.0           235133                   1.0
# 65                      25.0     109.0            18140                   1.0
# 66                     121.0     104.0            23986                   0.0
# 67                      62.0     124.0            35130                   3.0
# 68                      71.0      98.0            81599                   3.0
# 69                     134.0      88.0           160281                   0.0
# 70                     212.0      89.0            46492                   0.0
# 71                     212.0      89.0            46493                   0.0
# 72                      46.0     124.0            12974                   0.0
# 73                      13.0      98.0             2061                   0.0
# 74                     234.0     115.0           661017                   1.0
# 75                      25.0      98.0             1400                   0.0
# 76                      60.0     108.0            10832                   0.0
# 77                      50.0     102.0             1275                   0.0
# 78                       2.0     118.0              892                   0.0
# 79                      52.0     117.0            48629                   1.0
# 80                     242.0      87.0            39690                   0.0
# 81                     161.0      91.0            22773                   0.0
# 82                      11.0     114.0             7748                   2.0
# 83                     302.0     117.0           461609                   2.0
# 84                      94.0     116.0            77366                   1.0
# 85                      43.0     136.0            19832                   1.0
# 86                     166.0     129.0           113065                   0.0
# 87                     166.0     129.0           113068                   0.0
# 88                      40.0      99.0             2541                   2.0
# 89                      79.0     129.0            26310                   0.0
# 90                     297.0     109.0           258078                   0.0
# 91                     148.0     116.0            91414                   2.0
# 92                     223.0     120.0           105446                   0.0
# 93                     223.0     120.0           105448                   0.0
# 94                     215.0     120.0           281842                   0.0
# 95                      42.0     110.0            14995                   6.0
# 96                     235.0      91.0            31952                   0.0
# 97                     162.0      98.0            28589                   0.0
# 98                     197.0     134.0           681857                   0.0
# 99                      80.0     193.0            45271                   0.0
# ...                      ...       ...              ...                   ...
# 3027                   204.0      99.0            66123                   4.0
# 3028                    76.0      94.0            23473                   1.0
# 3029                   305.0     124.0           147128                   0.0
# 3030                   478.0     121.0           196217                   2.0
# 3031                   221.0     115.0            97697                   8.0
# 3032                   349.0     167.0           119928                   0.0
# 3033                   426.0     130.0           182983                   4.0
# 3034                   125.0     107.0            11476                   2.0
# 3035                   178.0     117.0            57674                   0.0
# 3036                   214.0     112.0            93767                   1.0
# 3037                   474.0     128.0           195333                   2.0
# 3038                    61.0     111.0            18915                   0.0
# 3039                   175.0     101.0            61360                   1.0
# 3040                    27.0     118.0             2302                   4.0
# 3041                   113.0     129.0            23480                   0.0
# 3042                    97.0     107.0             9051                  13.0
# 3043                   198.0      98.0            29867                   0.0
# 3044                   222.0     115.0            38202                   3.0
# 3045                   107.0      99.0            28159                   4.0
# 3046                    74.0     129.0             1758                   0.0
# 3047                   191.0     109.0            63390                   2.0
# 3048                   177.0     106.0            57349                   0.0
# 3049                     1.0     111.0              314                   1.0
# 3050                   189.0      97.0            25210                   0.0
# 3051                   139.0     106.0            20810                   0.0
# 3052                   131.0     122.0             7976                   0.0
# 3053                   132.0     101.0            51326                   4.0
# 3054                   256.0      95.0            30219                   2.0
# 3055                    93.0      91.0             7199                   0.0
# 3056                   328.0      90.0            31489                   0.0
# 3057                   180.0     103.0            56605                   3.0
# 3058                   133.0     103.0             5863                   0.0
# 3059                   371.0      94.0            65299                   0.0
# 3060                   297.0     108.0            79909                   1.0
# 3061                   297.0     108.0            79916                   1.0
# 3062                   203.0     103.0            48675                   0.0
# 3063                    12.0     121.0             2047                   0.0
# 3064                   322.0      95.0            28845                   0.0
# 3065                   149.0      91.0            27198                   1.0
# 3066                   425.0      92.0            66483                   0.0
# 3067                   152.0      83.0            28513                   0.0
# 3068                    11.0     120.0             4977                   5.0
# 3069                     4.0     125.0               22                   0.0
# 3070                    39.0      97.0             3911                   1.0
# 3071                   168.0     102.0            16645                   3.0
# 3072                    10.0      89.0              744                   6.0
# 3073                    36.0      97.0             1048                   1.0
# 3074                   159.0      81.0            13521                   0.0
# 3075                   516.0     147.0           272670                   0.0
# 3076                   673.0     183.0           371639                   0.0
# 3077                   322.0     122.0            53607                   4.0
# 3078                   248.0     110.0            42372                   2.0
# 3079                   248.0     110.0            42372                   2.0
# 3080                   396.0     144.0           148379                   6.0
# 3081                   418.0     123.0           118992                   8.0
# 3082                   218.0     113.0            21352                   1.0
# 3083                   286.0     120.0            58137                   0.0
# 3084                   275.0     123.0           111609                   0.0
# 3085                   210.0      95.0            64322                   0.0
# 3086                   464.0     116.0            69757                   4.0
# 3087                   464.0     116.0            69790                   4.0
# 3088                   184.0     126.0            51892                   4.0
# 3089                   181.0     112.0            17533                   0.0
# 3090                   231.0     120.0            37750                   2.0
# 3091                   181.0     120.0            44296                   3.0
# 3092                   196.0     129.0            40862                   6.0
# 3093                   141.0      97.0            27130                   0.0
# 3094                   579.0     108.0           479047                   0.0
# 3095                   177.0     107.0            33354                   2.0
# 3096                   204.0     144.0            47764                   0.0
# 3097                   226.0     102.0            34964                   4.0
# 3098                    79.0     139.0             3077                   1.0
# 3099                   300.0     134.0            64989                   0.0
# 3100                   119.0     102.0            28621                   0.0
# 3101                   148.0     110.0            39440                   4.0
# 3102                   194.0     112.0            55617                   0.0
# 3103                   177.0      92.0            28041                   0.0
# 3104                   154.0      99.0            16984                   1.0
# 3105                   225.0     108.0            23775                   0.0
# 3106                   268.0      98.0            19611                   1.0
# 3107                   123.0      98.0             8885                   0.0
# 3108                    81.0     100.0             4654                   9.0
# 3109                    81.0     100.0             4654                   9.0
# 3110                   122.0     107.0            12276                   2.0
# 3111                    86.0      96.0             4303                   0.0
# 3112                   214.0     115.0            32567                   3.0
# 3113                    24.0     111.0             1449                   0.0
# 3114                   156.0      94.0            13562                  10.0
# 3115                   186.0      86.0            12983                   0.0
# 3116                   411.0     104.0           126893                   0.0
# 3117                   129.0     100.0            15385                   2.0
# 3118                    63.0     109.0             6276                   0.0
# 3119                   158.0     109.0            49671                   1.0
# 3120                   159.0      97.0            35654                   0.0
# 3121                   185.0      93.0            20837                   1.0
# 3122                    29.0     120.0             4501                  11.0
# 3123                    59.0      92.0             9509                   4.0
# 3124                    12.0      96.0             1180                   6.0
# 3125                   159.0      81.0            13523                   0.0
# 3126                   178.0     117.0            27481                   0.0
#
#       num_user_for_reviews        budget  title_year  imdb_score  \
# 0                    175.0  2.614410e+07        1947         7.7
# 1                     54.0  3.815070e+07        1948         7.1
# 2                     90.0  3.913883e+07        1950         7.0
# 3                    107.0  3.692400e+07        1952         6.7
# 4                     69.0  4.582500e+07        1953         6.8
# 5                     88.0  1.924650e+06        1953         6.7
# 6                    281.0  8.247330e+06        1954         8.2
# 7                    350.0  2.427046e+07        1959         8.3
# 8                   1040.0  6.708150e+06        1960         8.5
# 9                    316.0  4.909200e+07        1961         7.6
# 10                   344.0  7.539740e+07        1963         7.6
# 11                   258.0  1.341470e+08        1964         7.9
# 12                   259.0  4.734600e+07        1964         7.8
# 13                    26.0  1.262560e+06        1964         8.1
# 14                   100.0  1.561200e+08        1965         6.6
# 15                   255.0  8.586600e+07        1965         8.0
# 16                   406.0  6.400920e+07        1965         8.0
# 17                    67.0  2.966280e+07        1965         6.8
# 18                   309.0  4.103400e+07        1969         8.1
# 19                    50.0  1.610500e+08        1970         6.2
# 20                   137.0  5.797800e+06        1970         6.2
# 21                    63.0  3.865200e+06        1970         8.1
# 22                   150.0  5.507100e+07        1971         8.0
# 23                    50.0  3.059500e+06        1971         5.5
# 24                    16.0  1.652130e+05        1971         6.7
# 25                  2238.0  3.555600e+07        1972         9.2
# 26                   183.0  5.926000e+04        1972         6.1
# 27                  1058.0  4.574400e+07        1973         8.0
# 28                   252.0  3.144900e+07        1973         8.3
# 29                   238.0  4.442886e+06        1973         7.5
# 30                   223.0  2.859000e+06        1973         7.4
# 31                   650.0  6.782100e+07        1974         9.0
# 32                   315.0  1.460760e+07        1974         8.0
# 33                   363.0  1.356420e+07        1974         7.8
# 34                    36.0  2.608500e+06        1974         6.1
# 35                   826.0  4.357864e+05        1974         7.5
# 36                   826.0  4.357864e+05        1974         7.5
# 37                   962.0  3.734400e+07        1975         8.0
# 38                   760.0  2.053920e+07        1975         8.7
# 39                   242.0  3.938400e+07        1976         6.8
# 40                   542.0  4.200960e+06        1976         8.1
# 41                   210.0  1.081340e+08        1977         7.4
# 42                   339.0  8.068822e+07        1977         7.7
# 43                  1470.0  4.574900e+07        1977         8.7
# 44                   491.0  1.663600e+07        1977         8.1
# 45                    84.0  2.079500e+06        1977         5.9
# 46                   497.0  2.141700e+08        1978         7.3
# 47                   150.0  9.345600e+07        1978         5.2
# 48                   265.0  7.788000e+07        1978         5.7
# 49                   350.0  2.336400e+07        1978         7.2
# 50                   257.0  1.168200e+07        1978         7.6
# 51                  1191.0  1.168200e+06        1978         7.9
# 52                  1191.0  1.168200e+06        1978         7.9
# 53                  1191.0  1.168200e+06        1978         7.9
# 54                   113.0  7.248250e+07        1978         8.2
# 55                   405.0  1.247400e+08        1979         6.4
# 56                   983.0  1.122660e+08        1979         8.5
# 57                    52.0  3.029400e+07        1979         6.9
# 58                   142.0  2.851200e+07        1979         7.6
# 59                   269.0  1.690200e+08        1980         6.8
# 60                   189.0  1.377200e+08        1980         6.8
# 61                   319.0  8.451000e+07        1980         7.9
# 62                    74.0  6.260000e+07        1980         4.5
# 63                   900.0  5.634000e+07        1980         8.8
# 64                   494.0  5.634000e+07        1980         8.3
# 65                    60.0  3.130000e+07        1980         6.1
# 66                   201.0  2.034500e+07        1980         7.1
# 67                   283.0  1.878000e+07        1980         7.8
# 68                   250.0  1.878000e+07        1980         7.4
# 69                   427.0  1.095500e+07        1980         7.8
# 70                   335.0  3.130000e+06        1980         6.8
# 71                   335.0  3.130000e+06        1980         6.8
# 72                    84.0  5.608800e+07        1980         7.5
# 73                    34.0  5.600000e+07        1981         5.4
# 74                   771.0  5.040000e+07        1981         8.5
# 75                    41.0  5.040000e+07        1981         5.0
# 76                   102.0  5.040000e+07        1981         6.7
# 77                    27.0  4.760000e+07        1981         6.4
# 78                    21.0  3.920000e+07        1981         5.2
# 79                   134.0  2.800000e+07        1981         6.9
# 80                   394.0  3.500000e+06        1981         6.1
# 81                   195.0  2.800000e+06        1981         6.6
# 82                    48.0  9.051000e+07        1982         5.8
# 83                  1168.0  7.240800e+07        1982         8.2
# 84                   194.0  5.689200e+07        1982         7.4
# 85                    98.0  5.430600e+07        1982         5.9
# 86                   337.0  5.172000e+07        1982         6.9
# 87                   337.0  5.172000e+07        1982         6.9
# 88                    54.0  5.172000e+07        1982         3.5
# 89                   154.0  4.137600e+07        1982         7.8
# 90                   911.0  3.879000e+07        1982         8.2
# 91                   359.0  2.844600e+07        1982         7.7
# 92                   321.0  2.767020e+07        1982         7.4
# 93                   321.0  2.767020e+07        1982         7.4
# 94                   515.0  2.715300e+07        1982         7.9
# 95                    87.0  1.293000e+07        1982         7.2
# 96                   372.0  1.034400e+07        1982         5.7
# 97                   532.0  6.465000e+06        1982         4.6
# 98                   647.0  8.105500e+07        1983         8.4
# 99                   170.0  6.733800e+07        1983         7.9
# ...                    ...           ...         ...         ...
# 3027                 219.0  3.220900e+07        2015         6.1
# 3028                 123.0  3.117000e+07        2015         4.4
# 3029                 277.0  3.117000e+07        2015         7.5
# 3030                 461.0  3.117000e+07        2015         7.6
# 3031                 185.0  3.013100e+07        2015         6.5
# 3032                 331.0  2.909200e+07        2015         7.9
# 3033                 374.0  2.909200e+07        2015         7.8
# 3034                  50.0  2.909200e+07        2015         6.1
# 3035                 126.0  2.701400e+07        2015         6.5
# 3036                 209.0  2.597500e+07        2015         7.2
# 3037                 409.0  2.078000e+07        2015         8.1
# 3038                  87.0  2.078000e+07        2015         6.8
# 3039                 129.0  2.078000e+07        2015         6.6
# 3040                  20.0  2.078000e+07        2015         7.0
# 3041                  83.0  1.766300e+07        2015         7.4
# 3042                  68.0  1.766300e+07        2015         5.7
# 3043                 181.0  1.558500e+07        2015         6.2
# 3044                 135.0  1.537720e+07        2015         5.7
# 3045                  96.0  1.454600e+07        2015         5.1
# 3046                  30.0  1.402650e+07        2015         4.5
# 3047                 160.0  1.246800e+07        2015         6.4
# 3048                 177.0  1.246800e+07        2015         6.4
# 3049                  10.0  1.246800e+07        2015         7.5
# 3050                 126.0  1.039000e+07        2015         5.2
# 3051                 100.0  1.039000e+07        2015         7.1
# 3052                  61.0  1.039000e+07        2015         5.3
# 3053                 116.0  8.831500e+06        2015         6.5
# 3054                 200.0  8.831500e+06        2015         5.6
# 3055                  53.0  8.826305e+06        2015         4.5
# 3056                 140.0  8.312000e+06        2015         7.3
# 3057                  89.0  7.273000e+06        2015         7.3
# 3058                  25.0  7.273000e+06        2015         6.5
# 3059                 455.0  5.195000e+06        2015         6.2
# 3060                 279.0  5.195000e+06        2015         7.1
# 3061                 279.0  5.195000e+06        2015         7.1
# 3062                 214.0  5.195000e+06        2015         6.8
# 3063                  29.0  5.195000e+06        2015         4.6
# 3064                 125.0  5.195000e+06        2015         7.1
# 3065                 131.0  4.156000e+06        2015         4.6
# 3066                 452.0  3.636500e+06        2015         6.8
# 3067                 126.0  3.428700e+06        2015         5.2
# 3068                  63.0  2.389700e+06        2015         5.9
# 3069                   1.0  2.181900e+06        2015         7.2
# 3070                  22.0  2.078000e+06        2015         5.3
# 3071                  72.0  2.078000e+06        2015         6.9
# 3072                  19.0  1.974100e+06        2015         7.2
# 3073                   7.0  1.039000e+06        2015         5.5
# 3074                 150.0  1.039000e+05        2015         4.2
# 3075                1022.0  2.562500e+08        2016         8.2
# 3076                3018.0  2.562500e+08        2016         6.9
# 3077                 432.0  1.896250e+08        2016         7.5
# 3078                 239.0  1.845000e+08        2016         6.6
# 3079                 239.0  1.845000e+08        2016         6.6
# 3080                 622.0  1.824500e+08        2016         7.3
# 3081                 971.0  1.793750e+08        2016         6.9
# 3082                 131.0  1.742500e+08        2016         6.4
# 3083                 520.0  1.691250e+08        2016         5.5
# 3084                 781.0  1.640000e+08        2016         7.3
# 3085                 145.0  1.486250e+08        2016         7.2
# 3086                1211.0  1.476000e+08        2016         5.5
# 3087                1211.0  1.476000e+08        2016         5.5
# 3088                 273.0  1.435000e+08        2016         5.5
# 3089                 115.0  1.383750e+08        2016         6.3
# 3090                 134.0  1.178750e+08        2016         6.1
# 3091                 144.0  1.127500e+08        2016         5.8
# 3092                 139.0  9.225000e+07        2016         6.9
# 3093                 126.0  7.482500e+07        2016         6.3
# 3094                1058.0  5.945000e+07        2016         8.1
# 3095                 110.0  5.125000e+07        2016         6.6
# 3096                 219.0  5.125000e+07        2016         7.4
# 3097                 150.0  5.125000e+07        2016         4.8
# 3098                  47.0  5.125000e+07        2016         6.7
# 3099                 279.0  4.100000e+07        2016         7.8
# 3100                  58.0  4.100000e+07        2016         5.9
# 3101                  83.0  3.895000e+07        2016         6.1
# 3102                 266.0  3.895000e+07        2016         5.2
# 3103                 111.0  3.587500e+07        2016         6.0
# 3104                  96.0  2.972500e+07        2016         5.3
# 3105                 134.0  2.870000e+07        2016         5.8
# 3106                 103.0  2.767500e+07        2016         6.7
# 3107                  56.0  2.562500e+07        2016         5.8
# 3108                  46.0  2.050000e+07        2016         6.7
# 3109                  46.0  2.050000e+07        2016         6.7
# 3110                 117.0  2.050000e+07        2016         6.3
# 3111                  35.0  2.050000e+07        2016         7.1
# 3112                 106.0  2.050000e+07        2016         6.3
# 3113                  30.0  1.896250e+07        2016         5.4
# 3114                 103.0  1.845000e+07        2016         6.1
# 3115                 139.0  1.742500e+07        2016         6.8
# 3116                 440.0  1.537500e+07        2016         7.3
# 3117                  84.0  1.537500e+07        2016         6.4
# 3118                  55.0  1.332500e+07        2016         6.8
# 3119                 166.0  1.178750e+07        2016         6.0
# 3120                 155.0  1.025000e+07        2016         6.0
# 3121                 127.0  1.025000e+07        2016         4.8
# 3122                 102.0  5.125000e+06        2016         3.4
# 3123                  53.0  5.125000e+06        2016         3.5
# 3124                   9.0  5.125000e+06        2016         4.5
# 3125                  95.0  5.022500e+06        2016         6.9
# 3126                 113.0  2.592500e+07        2016         6.8
#
#      content_rating           actor_1_name            director_name  \
# 0         Not Rated          Rita Hayworth             Orson Welles
# 1          Approved          Gladys Cooper        Vincente Minnelli
# 2            Passed            Keenan Wynn            George Sidney
# 3         Not Rated         Gloria Grahame         Cecil B. DeMille
# 4           Unrated         Richard Burton             Henry Koster
# 5          Approved          Kenneth Tobey            Eugène Lourié
# 6         Not Rated          Marlon Brando               Elia Kazan
# 7         Not Rated       Nehemiah Persoff             Billy Wilder
# 8                 R            Janet Leigh         Alfred Hitchcock
# 9           Unrated            Rita Moreno           Jerome Robbins
# 10         Approved       Jonathan Winters           Stanley Kramer
# 11         Approved           Jeremy Brett             George Cukor
# 12         Approved                Ed Wynn         Robert Stevenson
# 13        Not Rated           Yaphet Kotto           Michael Roemer
# 14                G          Martin Landau           George Stevens
# 15            PG-13         Julie Christie               David Lean
# 16                G         Eleanor Parker              Robert Wise
# 17         Approved           James Coburn            Sam Peckinpah
# 18                M         Katharine Ross          George Roy Hill
# 19                G            Rock Hudson            Blake Edwards
# 20                X         Charles Napier               Russ Meyer
# 21                R             Joe Cocker         Michael Wadleigh
# 22                G                  Topol           Norman Jewison
# 23                R              John Amos       Melvin Van Peebles
# 24        Not Rated             Don Brooks            James Bidgood
# 25                R              Al Pacino     Francis Ford Coppola
# 26            NC-17                 Divine              John Waters
# 27                R          Ellen Burstyn         William Friedkin
# 28               PG         Eileen Brennan          George Roy Hill
# 29               PG          Harrison Ford             George Lucas
# 30                R         Robert De Niro          Martin Scorsese
# 31                R         Robert De Niro     Francis Ford Coppola
# 32               PG          Madeline Kahn               Mel Brooks
# 33                R          Madeline Kahn               Mel Brooks
# 34                G         Frances Bavier                 Joe Camp
# 35                R          Gunnar Hansen              Tobe Hooper
# 36                R          Gunnar Hansen              Tobe Hooper
# 37               PG           Roy Scheider         Steven Spielberg
# 38                R       Scatman Crothers             Milos Forman
# 39               PG         Farrah Fawcett         Michael Anderson
# 40               PG     Sylvester Stallone         John G. Avildsen
# 41               PG            Ryan O'Neal     Richard Attenborough
# 42               PG            Bob Balaban         Steven Spielberg
# 43               PG          Harrison Ford             George Lucas
# 44               PG            Woody Allen              Woody Allen
# 45               PG           Woody Strode        John 'Bud' Cardos
# 46               PG          Marlon Brando           Richard Donner
# 47                G             Lena Horne             Sidney Lumet
# 48               PG           Roy Scheider           Jeannot Szwarc
# 49            PG-13     Olivia Newton-John           Randal Kleiser
# 50                R           John Belushi              John Landis
# 51                R       Jamie Lee Curtis           John Carpenter
# 52                R       Jamie Lee Curtis           John Carpenter
# 53                R       Jamie Lee Curtis           John Carpenter
# 54               PG            Ringo Starr          Martin Scorsese
# 55               PG          Leonard Nimoy              Robert Wise
# 56                R          Harrison Ford     Francis Ford Coppola
# 57                R            David Keith              Mark Rydell
# 58               PG         Clint Eastwood               Don Siegel
# 59               PG          Margot Kidder           Richard Lester
# 60                R           Jeff Bridges           Michael Cimino
# 61                R           John Belushi              John Landis
# 62               PG       Steve Guttenberg             Nancy Walker
# 63               PG          Harrison Ford           Irvin Kershner
# 64                R         Robert De Niro          Martin Scorsese
# 65                R         Eileen Brennan             Howard Zieff
# 66                X        Angie Dickinson           Brian De Palma
# 67                R           Adam Baldwin           Robert Redford
# 68                R            Bill Murray             Harold Ramis
# 69               PG           Peter Graves             Jim Abrahams
# 70                R       Jamie Lee Curtis           John Carpenter
# 71                R       Jamie Lee Curtis           John Carpenter
# 72               PG           Sissy Spacek            Michael Apted
# 73               PG                   Mako               Steve Rash
# 74               PG          Harrison Ford         Steven Spielberg
# 75               PG          Jason Robards        William A. Fraker
# 76               PG          Ian McDiarmid          Matthew Robbins
# 77               PG           Tippi Hedren            Noel Marshall
# 78               PG         Frank Langella    Franklin J. Schaffner
# 79                R            Bill Murray             Ivan Reitman
# 80                R           Betsy Palmer              Steve Miner
# 81                R         Patrick Macnee                Joe Dante
# 82                R           Dolly Parton            Colin Higgins
# 83                R          Harrison Ford             Ridley Scott
# 84               PG            Bill Murray           Sydney Pollack
# 85               PG         Clint Eastwood           Clint Eastwood
# 86                R          William Smith              John Milius
# 87                R          William Smith              John Milius
# 88               PG         Barry Bostwick              Hal Needham
# 89                R     Charlotte Rampling             Sidney Lumet
# 90                R        Wilford Brimley           John Carpenter
# 91               PG          Leonard Nimoy           Nicholas Meyer
# 92               PG       Heather O'Rourke              Tobe Hooper
# 93               PG       Heather O'Rourke              Tobe Hooper
# 94               PG           Henry Thomas         Steven Spielberg
# 95                R       Steve Guttenberg           Barry Levinson
# 96                R        Richard Brooker              Steve Miner
# 97                R             Tom Atkins        Tommy Lee Wallace
# 98               PG          Harrison Ford         Richard Marquand
# 99               PG           Dennis Quaid           Philip Kaufman
# ...             ...                    ...                      ...
# 3027              R        Chris Hemsworth       John Francis Daley
# 3028             PG          D.B. Woodside             Andy Fickman
# 3029              R        Jake Gyllenhaal            Antoine Fuqua
# 3030              R          Edgar Arreola         Denis Villeneuve
# 3031          PG-13          Anna Kendrick          Elizabeth Banks
# 3032              R            Aldis Hodge             F. Gary Gray
# 3033              R           Ryan Gosling               Adam McKay
# 3034              R         Dominic Flores       David Gordon Green
# 3035          PG-13          Ryan Reynolds             Tarsem Singh
# 3036          PG-13          Harrison Ford       Lee Toland Krieger
# 3037              R           Billy Crudup             Tom McCarthy
# 3038             PG          Jay Hernandez               Boaz Yakin
# 3039              R         Bradley Cooper               John Wells
# 3040             PG             Donny Boaz             Angelo Pizzo
# 3041             PG          Morgan Saylor                Niki Caro
# 3042          PG-13           Olivia Wilde            Jessie Nelson
# 3043          PG-13             Adam Scott        Michael Dougherty
# 3044              R             Matt Bomer           Gregory Jacobs
# 3045              R             Adam Scott               Steve Pink
# 3046              R          Jeremy Irvine          Roland Emmerich
# 3047          PG-13              Nat Wolff            Jake Schreier
# 3048          PG-13             Gary Weeks           Dean Israelite
# 3049              R    Christopher Lambert            Timothy Hines
# 3050              R            Laila Haley               Ciarán Foy
# 3051              R              Al Pacino             Dan Fogelman
# 3052              R              Brad Pitt      Angelina Jolie Pitt
# 3053          PG-13           Bella Thorne               Ari Sandel
# 3054          PG-13       Joely Richardson             Henry Hobson
# 3055          PG-13         Djimon Hounsou           Mark Neveldine
# 3056              R   Jennifer Jason Leigh             Duke Johnson
# 3057              R         Kimberly Elise            Rick Famuyiwa
# 3058          PG-13           Steve Carell            Peter Sollett
# 3059          PG-13            Ocean James       M. Night Shyamalan
# 3060              R          Busy Philipps            Joel Edgerton
# 3061              R          Busy Philipps            Joel Edgerton
# 3062              R        Sterling Jerins        John Erick Dowdle
# 3063          PG-13     Hayden Christensen           Michael Polish
# 3064              R           Alia Shawkat          Jeremy Saulnier
# 3065              R            Ryan Guzman                Rob Cohen
# 3066              R        Julian Richings            Robert Eggers
# 3067          PG-13           Olivia Wilde               David Gelb
# 3068          PG-13         Alexa PenaVega                 Jon Gunn
# 3069              R          Michael Derek          Robert Fontaine
# 3070          PG-13          David Oyelowo            Jerry Jameson
# 3071              R    Alexander Skarsgård          Marielle Heller
# 3072              R         Logan Browning               Jamal Hill
# 3073              R          Nora Zehetner       Benjamin Dickinson
# 3074              R          Pfeifer Brown             Travis Cluff
# 3075          PG-13      Robert Downey Jr.            Anthony Russo
# 3076          PG-13           Henry Cavill              Zack Snyder
# 3077          PG-13         Sofia Boutella               Justin Lin
# 3078          PG-13        Christoph Waltz              David Yates
# 3079          PG-13        Christoph Waltz              David Yates
# 3080          PG-13      Jennifer Lawrence             Bryan Singer
# 3081          PG-13             Will Smith               David Ayer
# 3082             PG            Johnny Depp              James Bobin
# 3083          PG-13          Vivica A. Fox          Roland Emmerich
# 3084          PG-13         Dominic Cooper             Duncan Jones
# 3085             PG           J.K. Simmons       Alessandro Carloni
# 3086          PG-13          Ed Begley Jr.                Paul Feig
# 3087          PG-13          Ed Begley Jr.                Paul Feig
# 3088          PG-13          Gerard Butler              Alex Proyas
# 3089          PG-13          Stephen Amell               Dave Green
# 3090          PG-13        Chris Hemsworth    Cedric Nicolas-Troyan
# 3091          PG-13            Naomi Watts         Robert Schwentke
# 3092          PG-13       Daniel Radcliffe               Jon M. Chu
# 3093             PG         Peter Dinklage              Clay Kaytis
# 3094              R          Ryan Reynolds               Tim Miller
# 3095          PG-13         Dwayne Johnson  Rawson Marshall Thurber
# 3096              R          Toby Stephens              Michael Bay
# 3097          PG-13         Milla Jovovich              Ben Stiller
# 3098              R    Matthew McConaughey                Gary Ross
# 3099              R           Javier Botet                James Wan
# 3100          PG-13            Olivia Munn                Tim Story
# 3101              R            Alison Brie         Christian Ditter
# 3102          PG-13     Chloë Grace Moretz               J Blakeson
# 3103              R     Chloë Grace Moretz         Nicholas Stoller
# 3104              R         Peter Dinklage              Ben Falcone
# 3105          PG-13             Matt Smith              Burr Steers
# 3106              R          Julia Roberts             Jodie Foster
# 3107              R        Natalie Portman           Gavin O'Connor
# 3108              R             Mila Kunis                Jon Lucas
# 3109              R             Mila Kunis                Jon Lucas
# 3110          PG-13            Peter Firth           Kevin Reynolds
# 3111          PG-13           Samira Wiley              Henry Joost
# 3112              R           Kate Winslet            John Hillcoat
# 3113          PG-13          Clive Russell          Cyrus Nowrasteh
# 3114          PG-13           Nia Vardalos               Kirk Jones
# 3115          PG-13          Óscar Jaenada       Jaume Collet-Serra
# 3116          PG-13         Bradley Cooper         Dan Trachtenberg
# 3117              R               Nia Long            Peter Atencio
# 3118             PG        Jennifer Garner          Patricia Riggen
# 3119              R         Robert De Niro                Dan Mazer
# 3120          PG-13           Lauren Cohan       William Brent Bell
# 3121          PG-13            Eoin Macken               Jason Zada
# 3122             PG    Benjamin A. Onyango             Harold Cronk
# 3123              R           Fred Willard           Michael Tiddes
# 3124              R          Donald Faison           Bille Woodruff
# 3125          PG-13            Billy Burke        David F. Sandberg
# 3126          PG-13  Michael Raymond-James          Craig Gillespie
#
#      gross_group
# 0            low
# 1        low-mid
# 2       high-mid
# 3           high
# 4           high
# 5       high-mid
# 6       high-mid
# 7           high
# 8           high
# 9           high
# 10          high
# 11          high
# 12          high
# 13           low
# 14      high-mid
# 15          high
# 16          high
# 17           low
# 18          high
# 19       low-mid
# 20      high-mid
# 21      high-mid
# 22          high
# 23      high-mid
# 24           low
# 25          high
# 26           low
# 27          high
# 28          high
# 29          high
# 30           low
# 31          high
# 32          high
# 33          high
# 34          high
# 35          high
# 36          high
# 37          high
# 38          high
# 39          high
# 40          high
# 41          high
# 42          high
# 43          high
# 44          high
# 45      high-mid
# 46          high
# 47      high-mid
# 48          high
# 49          high
# 50          high
# 51          high
# 52          high
# 53          high
# 54           low
# 55          high
# 56          high
# 57          high
# 58          high
# 59          high
# 60           low
# 61          high
# 62           low
# 63          high
# 64           low
# 65          high
# 66          high
# 67          high
# 68          high
# 69          high
# 70      high-mid
# 71      high-mid
# 72          high
# 73       low-mid
# 74          high
# 75       low-mid
# 76       low-mid
# 77           low
# 78           low
# 79          high
# 80      high-mid
# 81      high-mid
# 82          high
# 83      high-mid
# 84          high
# 85          high
# 86      high-mid
# 87      high-mid
# 88           low
# 89          high
# 90       low-mid
# 91          high
# 92          high
# 93          high
# 94          high
# 95       low-mid
# 96      high-mid
# 97       low-mid
# 98          high
# 99      high-mid
# ...          ...
# 3027    high-mid
# 3028    high-mid
# 3029    high-mid
# 3030    high-mid
# 3031        high
# 3032        high
# 3033    high-mid
# 3034         low
# 3035         low
# 3036     low-mid
# 3037    high-mid
# 3038    high-mid
# 3039         low
# 3040         low
# 3041    high-mid
# 3042     low-mid
# 3043    high-mid
# 3044    high-mid
# 3045         low
# 3046         low
# 3047     low-mid
# 3048     low-mid
# 3049         low
# 3050     low-mid
# 3051         low
# 3052         low
# 3053     low-mid
# 3054         low
# 3055         low
# 3056         low
# 3057     low-mid
# 3058         low
# 3059    high-mid
# 3060    high-mid
# 3061    high-mid
# 3062     low-mid
# 3063         low
# 3064         low
# 3065     low-mid
# 3066     low-mid
# 3067     low-mid
# 3068         low
# 3069         low
# 3070         low
# 3071         low
# 3072         low
# 3073         low
# 3074     low-mid
# 3075        high
# 3076        high
# 3077        high
# 3078        high
# 3079        high
# 3080        high
# 3081        high
# 3082    high-mid
# 3083        high
# 3084    high-mid
# 3085        high
# 3086        high
# 3087        high
# 3088     low-mid
# 3089    high-mid
# 3090    high-mid
# 3091    high-mid
# 3092    high-mid
# 3093        high
# 3094        high
# 3095        high
# 3096    high-mid
# 3097     low-mid
# 3098     low-mid
# 3099        high
# 3100    high-mid
# 3101    high-mid
# 3102     low-mid
# 3103    high-mid
# 3104    high-mid
# 3105         low
# 3106     low-mid
# 3107         low
# 3108    high-mid
# 3109    high-mid
# 3110     low-mid
# 3111     low-mid
# 3112         low
# 3113         low
# 3114    high-mid
# 3115    high-mid
# 3116    high-mid
# 3117     low-mid
# 3118    high-mid
# 3119     low-mid
# 3120     low-mid
# 3121     low-mid
# 3122     low-mid
# 3123         low
# 3124         low
# 3125    high-mid
# 3126     low-mid
#
# [3127 rows x 12 columns]

# %% [markdown]
# ### Process Input, Cross-product features

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
encoders = dict() 
categorical_headers = ['content_rating', 'actor_1_name', 'director_name']

for col in categorical_headers+['gross_group']:
    
    if col=="gross_group":
        tmp = LabelEncoder()
        df[col] = tmp.fit_transform(df[col])
    else:
        encoders[col] = LabelEncoder()
        df[col+'_int'] = encoders[col].fit_transform(df[col])

numeric_headers = ['num_critic_for_reviews', 'duration', 'num_voted_users', 
                   'facenumber_in_poster', 'num_user_for_reviews', 'title_year', 'imdb_score']

for col in numeric_headers:
    df[col] = df[col].astype(np.float)
    
    ss = StandardScaler()
    df[col] = ss.fit_transform(df[col].values.reshape(-1, 1))

# %%
# Now lets create a wide model 
# https://www.tensorflow.org/tutorials/wide_and_deep
def process_input(df, label_header, categ_headers, numeric_headers):
    # input: what ever you need it to be
    # output: (dict of feature columns as tensors), (labels as tensors)
    
    # ========Process Inputs=========
    # not much changes here, except we leave the numerics as tc.constants
    continuous_cols = {k: tf.constant(df[k].values) for k in numeric_headers}
    # and we shift these tensors to be sparse one-hot encoded values
    # Creates a dictionary mapping from each categorical feature column name (k)
    # to the values of that column stored in a tf.SparseTensor.
    categorical_cols = {k: tf.SparseTensor(
                              indices=[[i, 0] for i in range(df[k].size)],
                              values=df[k].values,
                              dense_shape=[df[k].size, 1])
                        for k in categ_headers}
    
    # Merges the two dictionaries into one.
    feature_cols = dict(categorical_cols)
    feature_cols.update(continuous_cols)
    
    # Convert the label column into a constant Tensor.
    label = None
    if label_header is not None:
        label = tf.constant(df[label_header].values)
        
    return feature_cols, label

# %%
import tensorflow as tf
from tensorflow.contrib import learn
from tensorflow.contrib import layers
from tensorflow.contrib.learn.python import SKCompat
from tensorflow.contrib.learn.python.learn.estimators import model_fn as model_fn_lib
tf.logging.set_verbosity(tf.logging.ERROR) # control the verbosity of tensor flow

# %%
# update the model to take input features as a dictionary
def setup_wide_deep_columns_1():
    # the prototype for this function is as follows
    # input:  (features, targets) 
    # output: (predictions, loss, train_op)
    
    wide_columns = []
    deep_columns = []
    # add in each of the categorical columns to both wide and deep features
    for col in categorical_headers:
        wide_columns.append(
            layers.sparse_column_with_keys(col, keys=encoders[col].classes_)
        )
        
        dim = round(np.log2(len(encoders[col].classes_)))
        deep_columns.append(
            layers.embedding_column(wide_columns[-1], dimension=dim)
        )
        
    # also add in some specific crossed columns
    cross_columns = [('actor_1_name', 'director_name')]
    for tup in cross_columns:
        wide_columns.append(
            layers.crossed_column(
                [layers.sparse_column_with_keys(tup[0], keys=encoders[tup[0]].classes_),
                 layers.sparse_column_with_keys(tup[1], keys=encoders[tup[1]].classes_)],
            hash_bucket_size=int(1e4))
        )
   
    # and add in the regular dense features 
    for col in numeric_headers:
        deep_columns.append(
            layers.real_valued_column(col)
        )
    return wide_columns, deep_columns

# %%
# update the model to take input features as a dictionary
def setup_wide_deep_columns_2():
    # the prototype for this function is as follows
    # input:  (features, targets) 
    # output: (predictions, loss, train_op)
    
    wide_columns = []
    deep_columns = []
    # add in each of the categorical columns to both wide and deep features
    for col in categorical_headers:
        wide_columns.append(
            layers.sparse_column_with_keys(col, keys=encoders[col].classes_)
        )
        
        dim = round(np.log2(len(encoders[col].classes_)))
        deep_columns.append(
            layers.embedding_column(wide_columns[-1], dimension=dim)
        )
        
    # also add in some specific crossed columns
    cross_columns = [('actor_1_name', 'director_name')]
    for tup in cross_columns:
        wide_columns.append(
            layers.crossed_column(
                [layers.sparse_column_with_keys(tup[0], keys=encoders[tup[0]].classes_),
                 layers.sparse_column_with_keys(tup[1], keys=encoders[tup[1]].classes_)],
            hash_bucket_size=int(1e4))
        )

        
    # and add in the regular dense features 
    for col in numeric_headers:
        deep_columns.append(
            layers.real_valued_column(col)
        )
                    
    return wide_columns, deep_columns

# %%
X = df.drop('gross_group', axis=1)
y = df['gross_group']

# %%
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
cv = StratifiedKFold(n_splits=3)
classes = [0, 1, 2, 3]
conf_list = [[],[]]
roc_list = [[],[]]
auc_list = [[],[]]

for train_idx, test_idx in cv.split(X,y):
    df_train, df_test = df.loc[train_idx], df.loc[test_idx]    

    
    input_wrapper = lambda:process_input(df_train,'gross_group',categorical_headers, numeric_headers)
    output_wrapper = lambda:process_input(df_test,None,categorical_headers, numeric_headers)
    
    wide_columns, deep_columns = setup_wide_deep_columns_1()
    clf1 = learn.DNNLinearCombinedClassifier(
                            n_classes=4,
                            linear_feature_columns=wide_columns,
                            dnn_feature_columns=deep_columns,
                            dnn_hidden_units=[100, 50])

    clf1.fit(input_fn=input_wrapper, steps=300)
    
    y_test = df_test['gross_group'].values
    yhat1 = clf1.predict(input_fn=output_wrapper)
    # the output is now an iterable value, so we need to step over it
    yhat1 = [x for x in yhat1]
    yhat1_probs = np.argmax([x for x in clf1.predict_proba(input_fn=output_wrapper)], axis=1)
    each_roc = []
    each_auc = []
    for x in classes:
        temp_roc = roc_curve(y_test, yhat1_probs, pos_label=x)
        each_roc.append(temp_roc)
        each_auc.append(auc(temp_roc[0], temp_roc[1]))
    roc_list[0].append(each_roc)
    auc_list[0].append(each_auc)
    conf_list[0].append(confusion_matrix(y_test, yhat1))

    

    clf2 = learn.DNNLinearCombinedClassifier(
                            n_classes=4,
                            linear_feature_columns=wide_columns,
                            dnn_feature_columns=deep_columns,
                            dnn_hidden_units=[80])

    clf2.fit(input_fn=input_wrapper, steps=300)
    yhat2 = clf2.predict(input_fn=output_wrapper)
    yhat2 = [x for x in yhat2]
    yhat2_probs = np.argmax([x for x in clf2.predict_proba(input_fn=output_wrapper)], axis=1)
    each_roc = []
    each_auc = []
    for x in classes:
        temp_roc = roc_curve(y_test, yhat2_probs, pos_label=x)
        each_roc.append(temp_roc)
        each_auc.append(auc(temp_roc[0], temp_roc[1]))
    roc_list[1].append(each_roc)
    auc_list[1].append(each_auc)
    conf_list[1].append(confusion_matrix(y_test, yhat2))

# %% [markdown]
# # Modeling
# ### Create a combined wide and deep network to classify data with tensorflow
