# %% [markdown]
# # Wide and Deep Neural Network

# %% [markdown]
# ### Introduction to Our Problem
# There are literally tens of thousands of movies out there today. While some do great at the box office and bring in a lot of money, others flop making only a fraction compared to the top hits. What if we had a scientific way of accurately predicting how much revenue a movie would generate over its lifetime? Well, through machine learning we believe that we actually can!
#
# The dataset we are using is found on <a href="https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset">Kaggle</a>. It consists of 5000+ movies scraped from the review site IMDB. There is quite a bit of data recorded for each movie and so we had a lot to work with to try to predict the next big hit. The data was collected from web scraping IMDB using a python library called "scrappy" to collect all of the data below. The features recorded for each movie are:
#
# Basic Info:
# - movie title
# - color (black and white or color)
# - duration of the movie
# - director name
# - gross (total revenue)
# - genres (a lits of different genres ascribed to the movie)
# - number of faces in movie poster
# - language of the movie
# - country the movie was produced in
# - content rating (G, PG, PG-13, R, NC-17)
# - budget
# - year of release
# - aspect ratio
# - name of the 3rd actor
# - name of the 2nd actor
# - name of the 1st actor
#
# Facebook Info:
# - number of director facebook likes
# - number of facebook likes for the whole cast
# - number of the movie's facebook likes
# - number of the 3rd actor's facebook likes
# - number of the 2nd actor's facebook likes
# - number of the 1st actor's facebook likes
#
# IMDB Specific Info:
# - number of imdb users who rated the movie
# - number of critical reviews for the movie
# - number of users who left a review
# - imdb score
# - top plot keywords
#
#
# With all of this data collected on so many movies, we hope to be able to use this to build out a multi-layer perceptron  to accurately predict the financial success (measured in categories of gross revenue: low, low-mid, high-mid, and high) of a movie. We think that this could be a useful tool to anyone in the movie industry who is concerned with making a profit on their movie. It could also help a producer understand which of these features are the most important to an accurate prediction, what content rating is most important, how budget affects outcome, etc.
#
#
# We believe that the algorithm would have to predict with a relatively low cost (under ~30) to be found useful by movie directors, producers, etc.

# %% [markdown]
# ### Data Pre-processing:
# We made a number of changes to both the original csv obtained from kaggle before we loaded it and to the data once it was loaded in.
#
#
# Pre-processing of the CSV:
# - We first removed the imdb link from the csv because we knew we would never need to use that (**Note: this was the only feature removed from the csv**)
# - We then went through and deleted all of the movies that were made in another country (foriegn films) we did this because we wanted to just look at American films, also because the currency units for those countries (for budget and gross) were in native currency units, not USD, and with changing exchange rates, it's not very easy to compare across countries.
# - We then went through and converted all 0 values for gross, movie_facebook_likes, and director_facebook_likes to a blank value in the csv (so that it is read in as NaN by pandas), this is so that we cna more easily impute values later. Note: according to the description on the kaggle entry, because of the way the data was scraped, some movies had missing data. The Python scraper just made these values into a 0 instead of NaN.
# - We then removed all movies with an undefined gross. Being the feature we are trying to predict, we should not be imputing values for gross to train our model. That will basically reduce our model to an imputation algorithm...
# - We then removed all movies that were made before 1935. We did this because there were only a handful of movies ranging from 1915 to 1935, the way we are classifying budget (described below) would not work with a small sample of movies from that time period. We could have cut this number at a different year (say 1960), but we didn't want to exclude such classics as "Bambi" or "Gone With the Wind"
# - Lastly, we had to adjust the gross revenue and budget values for inflation, since the movies spanned many years. For adjusting for inflation we obtained a csv of consumer price index (CPI) for every month since 1947. To simplify, we just took the value for January of that year to use for the whole year. We then took the CPI and calculated the ratio per year compared to 2017 dollars. We then took the budget and gross and multiplied them out with their appropriate ratio value. We then exported this to the csv that we use for the rest of this lab. **NB:** This was done outside of this notebook because this whole process took a very long time when it was included in the notebook when done every time.

# %% [markdown]
# Pre-processing of the Data:
# - After the above steps, we made more edits to the data using pandas. First, we removed features that we thought would be un-useful to our prediction algorithm. We removed all features concerning facebook likes. We did this because a significant portion of the movies in the training set debuted before facebook was invented and widely adopted. While some of these movies have received retroactive "likes" on facebook, only the most famous classics received a substantial amount of retraoctive "likes". Most lesser known films received very low amounts of "likes" (presumably because modern movie watchers don't really care to search for lesser known movies on facebook, or because the movie doesn't have a facebook). For this reason we decided to remove movie_facebook_likes
# - Likewise, we removed the other "likes" for the same reasons as above. For example, the esteemed director George Lucas has a total of 0 "likes" between all of his films. This feature obviously would not help us predict the profitability of movies.
# - We also removed irrelevant information such as aspect_ratio, language, and country. Because we deleted all foreign films the country will always be USA. A simple filter of the data reveals that there are no more than 20 movies made in the US that use a language other than English, therefore there is not enough data to use language as training feature. However, we did not delete the movies in a different language, because most of them were famous films such as *Letters from Iwo Jima* and *The Kite Runner*. We still count them as a valuable part of the dataset, just don't find the language of particular value. Lastly, we removed aspect_ratio because that seems to be unimportant for predicting the success of a movie.
# - Lastly, we removed other features that would be difficult to use in our machine learning model such as actor names and plot keywords. We initially tried to include these in our model using one-hot encoding, but the resultant array was so enormous that the model would take a very, very long time to train.

# %%
# Take the dataframe and adjust for inflation and then use the df_to_csv function to export to csv 
# and then export to csv and then delete code

import pandas as pd
import numpy as np
df = pd.read_csv("inflation_corrected_dataset.csv")
for x in ['movie_facebook_likes', 'director_facebook_likes', 'actor_2_facebook_likes', 
          'actor_1_facebook_likes','actor_3_facebook_likes', 'cast_total_facebook_likes',
          'aspect_ratio', 'language', 'country', 'plot_keywords', 'actor_3_name', 'actor_2_name', 'movie_title', 'genres', 'color']:
    if x in df:
        del df[x]
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3222 entries, 0 to 3221
# Data columns (total 12 columns):
# director_name             3222 non-null object
# num_critic_for_reviews    3219 non-null float64
# duration                  3221 non-null float64
# gross                     3222 non-null int64
# actor_1_name              3220 non-null object
# num_voted_users           3222 non-null int64
# facenumber_in_poster      3216 non-null float64
# num_user_for_reviews      3221 non-null float64
# content_rating            3196 non-null object
# budget                    3062 non-null float64
# title_year                3222 non-null int64
# imdb_score                3222 non-null float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 302.1+ KB
# None

# %% [markdown]
# Below we group the columns by director_name and then impute as many values as we can, dropping the rows where we can't impute.

# %%
# Tamper with the groupings to improve imputations? How do we improve how many values get imputed?
df_grouped = df.groupby(by=['director_name'])
# director_name adds about 50 rows (imputes about 50 rows and then deletes about 100)

# %%
df_imputed = df_grouped.transform(lambda grp: grp.fillna(grp.median()))
col_deleted = list( set(df.columns) - set(df_imputed.columns)) #in case the median op deleted columns
df_imputed[col_deleted] = df[col_deleted]

# drop rows that still have missing values after imputation
df_imputed.dropna(inplace=True)
print(df_imputed.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3127 entries, 0 to 3220
# Data columns (total 12 columns):
# num_critic_for_reviews    3127 non-null float64
# duration                  3127 non-null float64
# gross                     3127 non-null int64
# num_voted_users           3127 non-null int64
# facenumber_in_poster      3127 non-null float64
# num_user_for_reviews      3127 non-null float64
# budget                    3127 non-null float64
# title_year                3127 non-null int64
# imdb_score                3127 non-null float64
# content_rating            3127 non-null object
# actor_1_name              3127 non-null object
# director_name             3127 non-null object
# dtypes: float64(6), int64(3), object(3)
# memory usage: 317.6+ KB
# None

# %% [markdown]
# ### Scaling the Data
# Below we scale the data using the methods shown so as to not adversely affect the gamma value. We scaled down all of the numerical values to be within -1 and 1. We also one-hot encode the content rating. We forego encoding the director name or actor names because they proved to make our matrix way too large to run computations on.

# %%
# %%time
#scaling budgets!
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_rows', 200)

budget = df_imputed['budget'].values.reshape(-1, 1)
df_imputed.reset_index(drop=True, inplace=True)
print("df: ",df_imputed.shape)

append_list = [df_imputed]

df = pd.concat(append_list, axis=1)

#one-hot encode
hot_content = pd.get_dummies(df_imputed.content_rating, prefix='contentRating')

print(df.shape)
# Out:
# df:  (3127, 12)
# (3127, 12)
# Wall time: 5.51 ms

# %% [markdown]
# ### Cutting the gross into categories
# Below we cut the adjusted, scaled, gross into 4 main categories: low, low-mid, high-mid, and high. We did this because otherwise the model would not be able to produce raw gross accurately. We also used the "qcut" function to evenly distribute the classes among the classifications, because when we did a normal cut method most of the classes would fall in the lowest category and throw off our predictions.

# %%
from sklearn.preprocessing import LabelEncoder

spacing = np.linspace(0, max(df['gross']), 100)
labels = []

labels = ["low", "low-mid", "high-mid", "high"]
df['gross_group'] = pd.qcut(df['gross'], 4, labels=labels)


rating_group = df['gross_group'].values
rating_encoder = LabelEncoder()
rating_df = pd.DataFrame(rating_encoder.fit_transform(rating_group), columns=['encoded_gross']).astype(str)
df = pd.concat([df, rating_df], axis=1)
# Out:
#       num_critic_for_reviews  duration       gross  num_voted_users  \
# 0                       90.0      92.0       90106            19236
# 1                       41.0     102.0    30479316             3258
# 2                       21.0     107.0    83080000             3167
# 3                       44.0     152.0   332316000             9456
# 4                       42.0     135.0   329939999             6359
# 5                       67.0      80.0    45824999             4812
# 6                      134.0     108.0    87004799           100890
# 7                      181.0     120.0   210400000           175196
# 8                      290.0     108.0   266015999           422432
# 9                      120.0     152.0   357144300            71919
# 10                      61.0     197.0   371372300            29323
# 11                      82.0     170.0   568152000            66959
# 12                     145.0     139.0   807249300           107408
# 13                      24.0      95.0       98148              891
# 14                      27.0     225.0    62448000             6484
# 15                      89.0     200.0   872101932            55816
# 16                     119.0     174.0  1274050716           148172
# 17                      53.0     152.0      116098             5294
# 18                     130.0     110.0   699690567           152089
# 19                      22.0     143.0    32210000             1547
# 20                     101.0     109.0    57978000             7584
# 21                      53.0     215.0    85678600            12631
# 22                      66.0     181.0   305950000            29839
# 23                      38.0      97.0    92886420             3340
# 24                       8.0      65.0       50365              803
# 25                     208.0     175.0   798954887          1155770
# 26                      73.0     108.0     1069542            16792
# 27                     304.0     132.0  1169702670           284252
# 28                     119.0     129.0   912592800           175607
# 29                     100.0     112.0   657570000            63839
# 30                     112.0     112.0      186664            67797
# 31                     149.0     220.0   298934100           790926
# 32                     129.0     106.0   450227100           112671
# 33                     121.0      93.0   623431500            95294
# 34                       5.0      86.0   206345914             3411
# 35                     277.0      88.0   160991403            96410
# 36                     277.0      88.0   160991403            96411
# 37                     385.0     130.0  1213680000           412454
# 38                     149.0     133.0   522816000           680041
# 39                     112.0     119.0   109400000            39847
# 40                     141.0     145.0   513021440           375240
# 41                      56.0     175.0   211277200            40277
# 42                     171.0     135.0   533599700           139288
# 43                     282.0     125.0  1917031430           911097
# 44                     154.0      93.0   163032800           192940
# 45                      95.0      97.0    70703000             3274
# 46                     169.0     188.0   522644962           126357
# 47                      32.0     118.0    50621999            10895
# 48                      75.0     131.0   400779732            51314
# 49                     124.0     110.0   706215840           170027
# 50                      94.0     109.0   551390400            90177
# 51                     318.0     101.0   183018000           157857
# 52                     318.0     101.0   183018000           157857
# 53                     318.0     101.0   183018000           157863
# 54                      71.0     117.0     1253681            12611
# 55                     134.0     143.0   293317199            63330
# 56                     261.0     289.0   280843199           450676
# 57                      32.0     125.0   104068799             6142
# 58                      53.0     112.0   130085999            87090
# 59                     121.0     116.0   338666000            76331
# 60                     102.0     325.0     4695000             9830
# 61                     125.0     148.0   169646000           142448
# 62                      26.0     124.0     6260000             2998
# 63                     223.0     127.0   908196890           837759
# 64                     151.0     121.0      141632           235133
# 65                      25.0     109.0   218474000            18140
# 66                     121.0     104.0    99843870            23986
# 67                      62.0     124.0   171524000            35130
# 68                      71.0      98.0   124574000            81599
# 69                     134.0      88.0   261042000           160281
# 70                     212.0      89.0    66913140            46492
# 71                     212.0      89.0    66913140            46493
# 72                      46.0     124.0   250087000            12974
# 73                      13.0      98.0    23800000             2061
# 74                     234.0     115.0   678648471           661017
# 75                      25.0      98.0    22400000             1400
# 76                      60.0     108.0    16800000            10832
# 77                      50.0     102.0     5600000             1275
# 78                       2.0     118.0     2240000              892
# 79                      52.0     117.0   238839999            48629
# 80                     242.0      87.0    53480000            39690
# 81                     161.0      91.0    50360800            22773
# 82                      11.0     114.0   180244200             7748
# 83                     302.0     117.0    69822000           461609
# 84                      94.0     116.0   458239200            77366
# 85                      43.0     136.0   120766200            19832
# 86                     166.0     129.0    97149399           113065
# 87                     166.0     129.0    97149399           113068
# 88                      40.0      99.0    13792839             2541
# 89                      79.0     129.0   139644000            26310
# 90                     297.0     109.0    35642419           258078
# 91                     148.0     116.0   204035400            91414
# 92                     223.0     120.0   198087600           105446
# 93                     223.0     120.0   198087600           105448
# 94                     215.0     120.0  1124779300           281842
# 95                      42.0     110.0    36462600            14995
# 96                     235.0      91.0    93613200            31952
# 97                     162.0      98.0    37238400            28589
# 98                     197.0     134.0   770958770           681857
# 99                      80.0     193.0    53621000            45271
# ...                      ...       ...         ...              ...
# 3027                   204.0      99.0    61175418            66123
# 3028                    76.0      94.0    73808679            23473
# 3029                   305.0     124.0    54463239           147128
# 3030                   478.0     121.0    48703611           196217
# 3031                   221.0     115.0   190590398            97697
# 3032                   349.0     167.0   167309411           119928
# 3033                   426.0     130.0    72974499           182983
# 3034                   125.0     107.0     7271258            11476
# 3035                   178.0     117.0    12755605            57674
# 3036                   214.0     112.0    44134823            93767
# 3037                   474.0     128.0    46742719           195333
# 3038                    61.0     111.0    44315431            18915
# 3039                   175.0     101.0    14183116            61360
# 3040                    27.0     118.0     2333594             2302
# 3041                   113.0     129.0    46203916            23480
# 3042                    97.0     107.0    27309569             9051
# 3043                   198.0      98.0    44253638            29867
# 3044                   222.0     115.0    68584361            38202
# 3045                   107.0      99.0    12761701            28159
# 3046                    74.0     129.0      193621             1758
# 3047                   191.0     109.0    33237676            63390
# 3048                   177.0     106.0    23201938            57349
# 3049                     1.0     111.0       15186              314
# 3050                   189.0      97.0    28818513            25210
# 3051                   139.0     106.0     5556901            20810
# 3052                   131.0     122.0      551718             7976
# 3053                   132.0     101.0    35344550            51326
# 3054                   256.0      95.0      136290            30219
# 3055                    93.0      91.0     1778883             7199
# 3056                   328.0      90.0     3577089            31489
# 3057                   180.0     103.0    18155597            56605
# 3058                   133.0     103.0      553774             5863
# 3059                   371.0      94.0    67606836            65299
# 3060                   297.0     108.0    45478371            79909
# 3061                   297.0     108.0    45478371            79916
# 3062                   203.0     103.0    28350105            48675
# 3063                    12.0     121.0     4883675             2047
# 3064                   322.0      95.0     3344571            28845
# 3065                   149.0      91.0    36765596            27198
# 3066                   425.0      92.0    26118685            66483
# 3067                   152.0      83.0    26805205            28513
# 3068                    11.0     120.0    13491692             4977
# 3069                     4.0     125.0        3459               22
# 3070                    39.0      97.0     2657417             3911
# 3071                   168.0     102.0     1534605            16645
# 3072                    10.0      89.0      461361              744
# 3073                    36.0      97.0       64916             1048
# 3074                   159.0      81.0    23645373            13521
# 3075                   516.0     147.0   417377214           272670
# 3076                   673.0     183.0   338505288           371639
# 3077                   322.0     122.0   133730341            53607
# 3078                   248.0     110.0   127153052            42372
# 3079                   248.0     110.0   127153052            42372
# 3080                   396.0     144.0   158859714           148379
# 3081                   418.0     123.0   165114362           118992
# 3082                   218.0     113.0    78767789            21352
# 3083                   286.0     120.0   104873433            58137
# 3084                   275.0     123.0    48153469           111609
# 3085                   210.0      95.0   147111549            64322
# 3086                   464.0     116.0   121052150            69757
# 3087                   464.0     116.0   121052150            69790
# 3088                   184.0     126.0    31919600            51892
# 3089                   181.0     112.0    83679640            17533
# 3090                   231.0     120.0    49150820            37750
# 3091                   181.0     120.0    67652247            44296
# 3092                   196.0     129.0    66302492            40862
# 3093                   141.0      97.0   109905793            27130
# 3094                   579.0     108.0   372099869           479047
# 3095                   177.0     107.0   129241098            33354
# 3096                   204.0     144.0    54142978            47764
# 3097                   226.0     102.0    29558042            34964
# 3098                    79.0     139.0    20899716             3077
# 3099                   300.0     134.0   104867929            64989
# 3100                   119.0     102.0    93105905            28621
# 3101                   148.0     110.0    47983700            39440
# 3102                   194.0     112.0    35785806            55617
# 3103                   177.0      92.0    56674110            28041
# 3104                   154.0      99.0    64610623            16984
# 3105                   225.0     108.0    11179973            23775
# 3106                   268.0      98.0    42033745            19611
# 3107                   123.0      98.0     1550635             8885
# 3108                    81.0     100.0    56847839             4654
# 3109                    81.0     100.0    56847839             4654
# 3110                   122.0     107.0    37796613            12276
# 3111                    86.0      96.0    29598847             4303
# 3112                   214.0     115.0    12942577            32567
# 3113                    24.0     111.0     6624140             1449
# 3114                   156.0      94.0    61062412            13562
# 3115                   186.0      86.0    55613868            12983
# 3116                   411.0     104.0    73694645           126893
# 3117                   129.0     100.0    21080485            15385
# 3118                    63.0     109.0    63235861             6276
# 3119                   158.0     109.0    36426003            49671
# 3120                   159.0      97.0    36689020            35654
# 3121                   185.0      93.0    27247953            20837
# 3122                    29.0     120.0    21292396             4501
# 3123                    59.0      92.0    11967057             9509
# 3124                    12.0      96.0     9899829             1180
# 3125                   159.0      81.0    57949416            13523
# 3126                   178.0     117.0    28239503            27481
#
#       facenumber_in_poster  num_user_for_reviews        budget  title_year  \
# 0                      1.0                 175.0  2.614410e+07        1947
# 1                      0.0                  54.0  3.815070e+07        1948
# 2                      0.0                  90.0  3.913883e+07        1950
# 3                      0.0                 107.0  3.692400e+07        1952
# 4                      1.0                  69.0  4.582500e+07        1953
# 5                      0.0                  88.0  1.924650e+06        1953
# 6                      2.0                 281.0  8.247330e+06        1954
# 7                      2.0                 350.0  2.427046e+07        1959
# 8                      2.0                1040.0  6.708150e+06        1960
# 9                      0.0                 316.0  4.909200e+07        1961
# 10                     0.0                 344.0  7.539740e+07        1963
# 11                     1.0                 258.0  1.341470e+08        1964
# 12                     2.0                 259.0  4.734600e+07        1964
# 13                     1.0                  26.0  1.262560e+06        1964
# 14                     6.0                 100.0  1.561200e+08        1965
# 15                     2.0                 255.0  8.586600e+07        1965
# 16                     3.0                 406.0  6.400920e+07        1965
# 17                     2.0                  67.0  2.966280e+07        1965
# 18                     1.0                 309.0  4.103400e+07        1969
# 19                     2.0                  50.0  1.610500e+08        1970
# 20                     8.0                 137.0  5.797800e+06        1970
# 21                     0.0                  63.0  3.865200e+06        1970
# 22                     0.0                 150.0  5.507100e+07        1971
# 23                     1.0                  50.0  3.059500e+06        1971
# 24                     1.0                  16.0  1.652130e+05        1971
# 25                     1.0                2238.0  3.555600e+07        1972
# 26                     2.0                 183.0  5.926000e+04        1972
# 27                     0.0                1058.0  4.574400e+07        1973
# 28                     0.0                 252.0  3.144900e+07        1973
# 29                     1.0                 238.0  4.442886e+06        1973
# 30                     0.0                 223.0  2.859000e+06        1973
# 31                     1.0                 650.0  6.782100e+07        1974
# 32                     0.0                 315.0  1.460760e+07        1974
# 33                     0.0                 363.0  1.356420e+07        1974
# 34                     0.0                  36.0  2.608500e+06        1974
# 35                     0.0                 826.0  4.357864e+05        1974
# 36                     0.0                 826.0  4.357864e+05        1974
# 37                     0.0                 962.0  3.734400e+07        1975
# 38                     0.0                 760.0  2.053920e+07        1975
# 39                     1.0                 242.0  3.938400e+07        1976
# 40                     0.0                 542.0  4.200960e+06        1976
# 41                    14.0                 210.0  1.081340e+08        1977
# 42                     0.0                 339.0  8.068822e+07        1977
# 43                     1.0                1470.0  4.574900e+07        1977
# 44                     0.0                 491.0  1.663600e+07        1977
# 45                     0.0                  84.0  2.079500e+06        1977
# 46                     0.0                 497.0  2.141700e+08        1978
# 47                     0.0                 150.0  9.345600e+07        1978
# 48                     0.0                 265.0  7.788000e+07        1978
# 49                     2.0                 350.0  2.336400e+07        1978
# 50                     6.0                 257.0  1.168200e+07        1978
# 51                     0.0                1191.0  1.168200e+06        1978
# 52                     0.0                1191.0  1.168200e+06        1978
# 53                     0.0                1191.0  1.168200e+06        1978
# 54                     0.0                 113.0  7.248250e+07        1978
# 55                     2.0                 405.0  1.247400e+08        1979
# 56                     1.0                 983.0  1.122660e+08        1979
# 57                     0.0                  52.0  3.029400e+07        1979
# 58                     0.0                 142.0  2.851200e+07        1979
# 59                     4.0                 269.0  1.690200e+08        1980
# 60                     0.0                 189.0  1.377200e+08        1980
# 61                     1.0                 319.0  8.451000e+07        1980
# 62                     0.0                  74.0  6.260000e+07        1980
# 63                     0.0                 900.0  5.634000e+07        1980
# 64                     1.0                 494.0  5.634000e+07        1980
# 65                     1.0                  60.0  3.130000e+07        1980
# 66                     0.0                 201.0  2.034500e+07        1980
# 67                     3.0                 283.0  1.878000e+07        1980
# 68                     3.0                 250.0  1.878000e+07        1980
# 69                     0.0                 427.0  1.095500e+07        1980
# 70                     0.0                 335.0  3.130000e+06        1980
# 71                     0.0                 335.0  3.130000e+06        1980
# 72                     0.0                  84.0  5.608800e+07        1980
# 73                     0.0                  34.0  5.600000e+07        1981
# 74                     1.0                 771.0  5.040000e+07        1981
# 75                     0.0                  41.0  5.040000e+07        1981
# 76                     0.0                 102.0  5.040000e+07        1981
# 77                     0.0                  27.0  4.760000e+07        1981
# 78                     0.0                  21.0  3.920000e+07        1981
# 79                     1.0                 134.0  2.800000e+07        1981
# 80                     0.0                 394.0  3.500000e+06        1981
# 81                     0.0                 195.0  2.800000e+06        1981
# 82                     2.0                  48.0  9.051000e+07        1982
# 83                     2.0                1168.0  7.240800e+07        1982
# 84                     1.0                 194.0  5.689200e+07        1982
# 85                     1.0                  98.0  5.430600e+07        1982
# 86                     0.0                 337.0  5.172000e+07        1982
# 87                     0.0                 337.0  5.172000e+07        1982
# 88                     2.0                  54.0  5.172000e+07        1982
# 89                     0.0                 154.0  4.137600e+07        1982
# 90                     0.0                 911.0  3.879000e+07        1982
# 91                     2.0                 359.0  2.844600e+07        1982
# 92                     0.0                 321.0  2.767020e+07        1982
# 93                     0.0                 321.0  2.767020e+07        1982
# 94                     0.0                 515.0  2.715300e+07        1982
# 95                     6.0                  87.0  1.293000e+07        1982
# 96                     0.0                 372.0  1.034400e+07        1982
# 97                     0.0                 532.0  6.465000e+06        1982
# 98                     0.0                 647.0  8.105500e+07        1983
# 99                     0.0                 170.0  6.733800e+07        1983
# ...                    ...                   ...           ...         ...
# 3027                   4.0                 219.0  3.220900e+07        2015
# 3028                   1.0                 123.0  3.117000e+07        2015
# 3029                   0.0                 277.0  3.117000e+07        2015
# 3030                   2.0                 461.0  3.117000e+07        2015
# 3031                   8.0                 185.0  3.013100e+07        2015
# 3032                   0.0                 331.0  2.909200e+07        2015
# 3033                   4.0                 374.0  2.909200e+07        2015
# 3034                   2.0                  50.0  2.909200e+07        2015
# 3035                   0.0                 126.0  2.701400e+07        2015
# 3036                   1.0                 209.0  2.597500e+07        2015
# 3037                   2.0                 409.0  2.078000e+07        2015
# 3038                   0.0                  87.0  2.078000e+07        2015
# 3039                   1.0                 129.0  2.078000e+07        2015
# 3040                   4.0                  20.0  2.078000e+07        2015
# 3041                   0.0                  83.0  1.766300e+07        2015
# 3042                  13.0                  68.0  1.766300e+07        2015
# 3043                   0.0                 181.0  1.558500e+07        2015
# 3044                   3.0                 135.0  1.537720e+07        2015
# 3045                   4.0                  96.0  1.454600e+07        2015
# 3046                   0.0                  30.0  1.402650e+07        2015
# 3047                   2.0                 160.0  1.246800e+07        2015
# 3048                   0.0                 177.0  1.246800e+07        2015
# 3049                   1.0                  10.0  1.246800e+07        2015
# 3050                   0.0                 126.0  1.039000e+07        2015
# 3051                   0.0                 100.0  1.039000e+07        2015
# 3052                   0.0                  61.0  1.039000e+07        2015
# 3053                   4.0                 116.0  8.831500e+06        2015
# 3054                   2.0                 200.0  8.831500e+06        2015
# 3055                   0.0                  53.0  8.826305e+06        2015
# 3056                   0.0                 140.0  8.312000e+06        2015
# 3057                   3.0                  89.0  7.273000e+06        2015
# 3058                   0.0                  25.0  7.273000e+06        2015
# 3059                   0.0                 455.0  5.195000e+06        2015
# 3060                   1.0                 279.0  5.195000e+06        2015
# 3061                   1.0                 279.0  5.195000e+06        2015
# 3062                   0.0                 214.0  5.195000e+06        2015
# 3063                   0.0                  29.0  5.195000e+06        2015
# 3064                   0.0                 125.0  5.195000e+06        2015
# 3065                   1.0                 131.0  4.156000e+06        2015
# 3066                   0.0                 452.0  3.636500e+06        2015
# 3067                   0.0                 126.0  3.428700e+06        2015
# 3068                   5.0                  63.0  2.389700e+06        2015
# 3069                   0.0                   1.0  2.181900e+06        2015
# 3070                   1.0                  22.0  2.078000e+06        2015
# 3071                   3.0                  72.0  2.078000e+06        2015
# 3072                   6.0                  19.0  1.974100e+06        2015
# 3073                   1.0                   7.0  1.039000e+06        2015
# 3074                   0.0                 150.0  1.039000e+05        2015
# 3075                   0.0                1022.0  2.562500e+08        2016
# 3076                   0.0                3018.0  2.562500e+08        2016
# 3077                   4.0                 432.0  1.896250e+08        2016
# 3078                   2.0                 239.0  1.845000e+08        2016
# 3079                   2.0                 239.0  1.845000e+08        2016
# 3080                   6.0                 622.0  1.824500e+08        2016
# 3081                   8.0                 971.0  1.793750e+08        2016
# 3082                   1.0                 131.0  1.742500e+08        2016
# 3083                   0.0                 520.0  1.691250e+08        2016
# 3084                   0.0                 781.0  1.640000e+08        2016
# 3085                   0.0                 145.0  1.486250e+08        2016
# 3086                   4.0                1211.0  1.476000e+08        2016
# 3087                   4.0                1211.0  1.476000e+08        2016
# 3088                   4.0                 273.0  1.435000e+08        2016
# 3089                   0.0                 115.0  1.383750e+08        2016
# 3090                   2.0                 134.0  1.178750e+08        2016
# 3091                   3.0                 144.0  1.127500e+08        2016
# 3092                   6.0                 139.0  9.225000e+07        2016
# 3093                   0.0                 126.0  7.482500e+07        2016
# 3094                   0.0                1058.0  5.945000e+07        2016
# 3095                   2.0                 110.0  5.125000e+07        2016
# 3096                   0.0                 219.0  5.125000e+07        2016
# 3097                   4.0                 150.0  5.125000e+07        2016
# 3098                   1.0                  47.0  5.125000e+07        2016
# 3099                   0.0                 279.0  4.100000e+07        2016
# 3100                   0.0                  58.0  4.100000e+07        2016
# 3101                   4.0                  83.0  3.895000e+07        2016
# 3102                   0.0                 266.0  3.895000e+07        2016
# 3103                   0.0                 111.0  3.587500e+07        2016
# 3104                   1.0                  96.0  2.972500e+07        2016
# 3105                   0.0                 134.0  2.870000e+07        2016
# 3106                   1.0                 103.0  2.767500e+07        2016
# 3107                   0.0                  56.0  2.562500e+07        2016
# 3108                   9.0                  46.0  2.050000e+07        2016
# 3109                   9.0                  46.0  2.050000e+07        2016
# 3110                   2.0                 117.0  2.050000e+07        2016
# 3111                   0.0                  35.0  2.050000e+07        2016
# 3112                   3.0                 106.0  2.050000e+07        2016
# 3113                   0.0                  30.0  1.896250e+07        2016
# 3114                  10.0                 103.0  1.845000e+07        2016
# 3115                   0.0                 139.0  1.742500e+07        2016
# 3116                   0.0                 440.0  1.537500e+07        2016
# 3117                   2.0                  84.0  1.537500e+07        2016
# 3118                   0.0                  55.0  1.332500e+07        2016
# 3119                   1.0                 166.0  1.178750e+07        2016
# 3120                   0.0                 155.0  1.025000e+07        2016
# 3121                   1.0                 127.0  1.025000e+07        2016
# 3122                  11.0                 102.0  5.125000e+06        2016
# 3123                   4.0                  53.0  5.125000e+06        2016
# 3124                   6.0                   9.0  5.125000e+06        2016
# 3125                   0.0                  95.0  5.022500e+06        2016
# 3126                   0.0                 113.0  2.592500e+07        2016
#
#       imdb_score content_rating           actor_1_name  \
# 0            7.7      Not Rated          Rita Hayworth
# 1            7.1       Approved          Gladys Cooper
# 2            7.0         Passed            Keenan Wynn
# 3            6.7      Not Rated         Gloria Grahame
# 4            6.8        Unrated         Richard Burton
# 5            6.7       Approved          Kenneth Tobey
# 6            8.2      Not Rated          Marlon Brando
# 7            8.3      Not Rated       Nehemiah Persoff
# 8            8.5              R            Janet Leigh
# 9            7.6        Unrated            Rita Moreno
# 10           7.6       Approved       Jonathan Winters
# 11           7.9       Approved           Jeremy Brett
# 12           7.8       Approved                Ed Wynn
# 13           8.1      Not Rated           Yaphet Kotto
# 14           6.6              G          Martin Landau
# 15           8.0          PG-13         Julie Christie
# 16           8.0              G         Eleanor Parker
# 17           6.8       Approved           James Coburn
# 18           8.1              M         Katharine Ross
# 19           6.2              G            Rock Hudson
# 20           6.2              X         Charles Napier
# 21           8.1              R             Joe Cocker
# 22           8.0              G                  Topol
# 23           5.5              R              John Amos
# 24           6.7      Not Rated             Don Brooks
# 25           9.2              R              Al Pacino
# 26           6.1          NC-17                 Divine
# 27           8.0              R          Ellen Burstyn
# 28           8.3             PG         Eileen Brennan
# 29           7.5             PG          Harrison Ford
# 30           7.4              R         Robert De Niro
# 31           9.0              R         Robert De Niro
# 32           8.0             PG          Madeline Kahn
# 33           7.8              R          Madeline Kahn
# 34           6.1              G         Frances Bavier
# 35           7.5              R          Gunnar Hansen
# 36           7.5              R          Gunnar Hansen
# 37           8.0             PG           Roy Scheider
# 38           8.7              R       Scatman Crothers
# 39           6.8             PG         Farrah Fawcett
# 40           8.1             PG     Sylvester Stallone
# 41           7.4             PG            Ryan O'Neal
# 42           7.7             PG            Bob Balaban
# 43           8.7             PG          Harrison Ford
# 44           8.1             PG            Woody Allen
# 45           5.9             PG           Woody Strode
# 46           7.3             PG          Marlon Brando
# 47           5.2              G             Lena Horne
# 48           5.7             PG           Roy Scheider
# 49           7.2          PG-13     Olivia Newton-John
# 50           7.6              R           John Belushi
# 51           7.9              R       Jamie Lee Curtis
# 52           7.9              R       Jamie Lee Curtis
# 53           7.9              R       Jamie Lee Curtis
# 54           8.2             PG            Ringo Starr
# 55           6.4             PG          Leonard Nimoy
# 56           8.5              R          Harrison Ford
# 57           6.9              R            David Keith
# 58           7.6             PG         Clint Eastwood
# 59           6.8             PG          Margot Kidder
# 60           6.8              R           Jeff Bridges
# 61           7.9              R           John Belushi
# 62           4.5             PG       Steve Guttenberg
# 63           8.8             PG          Harrison Ford
# 64           8.3              R         Robert De Niro
# 65           6.1              R         Eileen Brennan
# 66           7.1              X        Angie Dickinson
# 67           7.8              R           Adam Baldwin
# 68           7.4              R            Bill Murray
# 69           7.8             PG           Peter Graves
# 70           6.8              R       Jamie Lee Curtis
# 71           6.8              R       Jamie Lee Curtis
# 72           7.5             PG           Sissy Spacek
# 73           5.4             PG                   Mako
# 74           8.5             PG          Harrison Ford
# 75           5.0             PG          Jason Robards
# 76           6.7             PG          Ian McDiarmid
# 77           6.4             PG           Tippi Hedren
# 78           5.2             PG         Frank Langella
# 79           6.9              R            Bill Murray
# 80           6.1              R           Betsy Palmer
# 81           6.6              R         Patrick Macnee
# 82           5.8              R           Dolly Parton
# 83           8.2              R          Harrison Ford
# 84           7.4             PG            Bill Murray
# 85           5.9             PG         Clint Eastwood
# 86           6.9              R          William Smith
# 87           6.9              R          William Smith
# 88           3.5             PG         Barry Bostwick
# 89           7.8              R     Charlotte Rampling
# 90           8.2              R        Wilford Brimley
# 91           7.7             PG          Leonard Nimoy
# 92           7.4             PG       Heather O'Rourke
# 93           7.4             PG       Heather O'Rourke
# 94           7.9             PG           Henry Thomas
# 95           7.2              R       Steve Guttenberg
# 96           5.7              R        Richard Brooker
# 97           4.6              R             Tom Atkins
# 98           8.4             PG          Harrison Ford
# 99           7.9             PG           Dennis Quaid
# ...          ...            ...                    ...
# 3027         6.1              R        Chris Hemsworth
# 3028         4.4             PG          D.B. Woodside
# 3029         7.5              R        Jake Gyllenhaal
# 3030         7.6              R          Edgar Arreola
# 3031         6.5          PG-13          Anna Kendrick
# 3032         7.9              R            Aldis Hodge
# 3033         7.8              R           Ryan Gosling
# 3034         6.1              R         Dominic Flores
# 3035         6.5          PG-13          Ryan Reynolds
# 3036         7.2          PG-13          Harrison Ford
# 3037         8.1              R           Billy Crudup
# 3038         6.8             PG          Jay Hernandez
# 3039         6.6              R         Bradley Cooper
# 3040         7.0             PG             Donny Boaz
# 3041         7.4             PG          Morgan Saylor
# 3042         5.7          PG-13           Olivia Wilde
# 3043         6.2          PG-13             Adam Scott
# 3044         5.7              R             Matt Bomer
# 3045         5.1              R             Adam Scott
# 3046         4.5              R          Jeremy Irvine
# 3047         6.4          PG-13              Nat Wolff
# 3048         6.4          PG-13             Gary Weeks
# 3049         7.5              R    Christopher Lambert
# 3050         5.2              R            Laila Haley
# 3051         7.1              R              Al Pacino
# 3052         5.3              R              Brad Pitt
# 3053         6.5          PG-13           Bella Thorne
# 3054         5.6          PG-13       Joely Richardson
# 3055         4.5          PG-13         Djimon Hounsou
# 3056         7.3              R   Jennifer Jason Leigh
# 3057         7.3              R         Kimberly Elise
# 3058         6.5          PG-13           Steve Carell
# 3059         6.2          PG-13            Ocean James
# 3060         7.1              R          Busy Philipps
# 3061         7.1              R          Busy Philipps
# 3062         6.8              R        Sterling Jerins
# 3063         4.6          PG-13     Hayden Christensen
# 3064         7.1              R           Alia Shawkat
# 3065         4.6              R            Ryan Guzman
# 3066         6.8              R        Julian Richings
# 3067         5.2          PG-13           Olivia Wilde
# 3068         5.9          PG-13         Alexa PenaVega
# 3069         7.2              R          Michael Derek
# 3070         5.3          PG-13          David Oyelowo
# 3071         6.9              R    Alexander Skarsgård
# 3072         7.2              R         Logan Browning
# 3073         5.5              R          Nora Zehetner
# 3074         4.2              R          Pfeifer Brown
# 3075         8.2          PG-13      Robert Downey Jr.
# 3076         6.9          PG-13           Henry Cavill
# 3077         7.5          PG-13         Sofia Boutella
# 3078         6.6          PG-13        Christoph Waltz
# 3079         6.6          PG-13        Christoph Waltz
# 3080         7.3          PG-13      Jennifer Lawrence
# 3081         6.9          PG-13             Will Smith
# 3082         6.4             PG            Johnny Depp
# 3083         5.5          PG-13          Vivica A. Fox
# 3084         7.3          PG-13         Dominic Cooper
# 3085         7.2             PG           J.K. Simmons
# 3086         5.5          PG-13          Ed Begley Jr.
# 3087         5.5          PG-13          Ed Begley Jr.
# 3088         5.5          PG-13          Gerard Butler
# 3089         6.3          PG-13          Stephen Amell
# 3090         6.1          PG-13        Chris Hemsworth
# 3091         5.8          PG-13            Naomi Watts
# 3092         6.9          PG-13       Daniel Radcliffe
# 3093         6.3             PG         Peter Dinklage
# 3094         8.1              R          Ryan Reynolds
# 3095         6.6          PG-13         Dwayne Johnson
# 3096         7.4              R          Toby Stephens
# 3097         4.8          PG-13         Milla Jovovich
# 3098         6.7              R    Matthew McConaughey
# 3099         7.8              R           Javier Botet
# 3100         5.9          PG-13            Olivia Munn
# 3101         6.1              R            Alison Brie
# 3102         5.2          PG-13     Chloë Grace Moretz
# 3103         6.0              R     Chloë Grace Moretz
# 3104         5.3              R         Peter Dinklage
# 3105         5.8          PG-13             Matt Smith
# 3106         6.7              R          Julia Roberts
# 3107         5.8              R        Natalie Portman
# 3108         6.7              R             Mila Kunis
# 3109         6.7              R             Mila Kunis
# 3110         6.3          PG-13            Peter Firth
# 3111         7.1          PG-13           Samira Wiley
# 3112         6.3              R           Kate Winslet
# 3113         5.4          PG-13          Clive Russell
# 3114         6.1          PG-13           Nia Vardalos
# 3115         6.8          PG-13          Óscar Jaenada
# 3116         7.3          PG-13         Bradley Cooper
# 3117         6.4              R               Nia Long
# 3118         6.8             PG        Jennifer Garner
# 3119         6.0              R         Robert De Niro
# 3120         6.0          PG-13           Lauren Cohan
# 3121         4.8          PG-13            Eoin Macken
# 3122         3.4             PG    Benjamin A. Onyango
# 3123         3.5              R           Fred Willard
# 3124         4.5              R          Donald Faison
# 3125         6.9          PG-13            Billy Burke
# 3126         6.8          PG-13  Michael Raymond-James
#
#                 director_name gross_group encoded_gross
# 0                Orson Welles         low             2
# 1           Vincente Minnelli     low-mid             3
# 2               George Sidney    high-mid             1
# 3            Cecil B. DeMille        high             0
# 4                Henry Koster        high             0
# 5               Eugène Lourié    high-mid             1
# 6                  Elia Kazan    high-mid             1
# 7                Billy Wilder        high             0
# 8            Alfred Hitchcock        high             0
# 9              Jerome Robbins        high             0
# 10             Stanley Kramer        high             0
# 11               George Cukor        high             0
# 12           Robert Stevenson        high             0
# 13             Michael Roemer         low             2
# 14             George Stevens    high-mid             1
# 15                 David Lean        high             0
# 16                Robert Wise        high             0
# 17              Sam Peckinpah         low             2
# 18            George Roy Hill        high             0
# 19              Blake Edwards     low-mid             3
# 20                 Russ Meyer    high-mid             1
# 21           Michael Wadleigh    high-mid             1
# 22             Norman Jewison        high             0
# 23         Melvin Van Peebles    high-mid             1
# 24              James Bidgood         low             2
# 25       Francis Ford Coppola        high             0
# 26                John Waters         low             2
# 27           William Friedkin        high             0
# 28            George Roy Hill        high             0
# 29               George Lucas        high             0
# 30            Martin Scorsese         low             2
# 31       Francis Ford Coppola        high             0
# 32                 Mel Brooks        high             0
# 33                 Mel Brooks        high             0
# 34                   Joe Camp        high             0
# 35                Tobe Hooper        high             0
# 36                Tobe Hooper        high             0
# 37           Steven Spielberg        high             0
# 38               Milos Forman        high             0
# 39           Michael Anderson        high             0
# 40           John G. Avildsen        high             0
# 41       Richard Attenborough        high             0
# 42           Steven Spielberg        high             0
# 43               George Lucas        high             0
# 44                Woody Allen        high             0
# 45          John 'Bud' Cardos    high-mid             1
# 46             Richard Donner        high             0
# 47               Sidney Lumet    high-mid             1
# 48             Jeannot Szwarc        high             0
# 49             Randal Kleiser        high             0
# 50                John Landis        high             0
# 51             John Carpenter        high             0
# 52             John Carpenter        high             0
# 53             John Carpenter        high             0
# 54            Martin Scorsese         low             2
# 55                Robert Wise        high             0
# 56       Francis Ford Coppola        high             0
# 57                Mark Rydell        high             0
# 58                 Don Siegel        high             0
# 59             Richard Lester        high             0
# 60             Michael Cimino         low             2
# 61                John Landis        high             0
# 62               Nancy Walker         low             2
# 63             Irvin Kershner        high             0
# 64            Martin Scorsese         low             2
# 65               Howard Zieff        high             0
# 66             Brian De Palma        high             0
# 67             Robert Redford        high             0
# 68               Harold Ramis        high             0
# 69               Jim Abrahams        high             0
# 70             John Carpenter    high-mid             1
# 71             John Carpenter    high-mid             1
# 72              Michael Apted        high             0
# 73                 Steve Rash     low-mid             3
# 74           Steven Spielberg        high             0
# 75          William A. Fraker     low-mid             3
# 76            Matthew Robbins     low-mid             3
# 77              Noel Marshall         low             2
# 78      Franklin J. Schaffner         low             2
# 79               Ivan Reitman        high             0
# 80                Steve Miner    high-mid             1
# 81                  Joe Dante    high-mid             1
# 82              Colin Higgins        high             0
# 83               Ridley Scott    high-mid             1
# 84             Sydney Pollack        high             0
# 85             Clint Eastwood        high             0
# 86                John Milius    high-mid             1
# 87                John Milius    high-mid             1
# 88                Hal Needham         low             2
# 89               Sidney Lumet        high             0
# 90             John Carpenter     low-mid             3
# 91             Nicholas Meyer        high             0
# 92                Tobe Hooper        high             0
# 93                Tobe Hooper        high             0
# 94           Steven Spielberg        high             0
# 95             Barry Levinson     low-mid             3
# 96                Steve Miner    high-mid             1
# 97          Tommy Lee Wallace     low-mid             3
# 98           Richard Marquand        high             0
# 99             Philip Kaufman    high-mid             1
# ...                       ...         ...           ...
# 3027       John Francis Daley    high-mid             1
# 3028             Andy Fickman    high-mid             1
# 3029            Antoine Fuqua    high-mid             1
# 3030         Denis Villeneuve    high-mid             1
# 3031          Elizabeth Banks        high             0
# 3032             F. Gary Gray        high             0
# 3033               Adam McKay    high-mid             1
# 3034       David Gordon Green         low             2
# 3035             Tarsem Singh         low             2
# 3036       Lee Toland Krieger     low-mid             3
# 3037             Tom McCarthy    high-mid             1
# 3038               Boaz Yakin    high-mid             1
# 3039               John Wells         low             2
# 3040             Angelo Pizzo         low             2
# 3041                Niki Caro    high-mid             1
# 3042            Jessie Nelson     low-mid             3
# 3043        Michael Dougherty    high-mid             1
# 3044           Gregory Jacobs    high-mid             1
# 3045               Steve Pink         low             2
# 3046          Roland Emmerich         low             2
# 3047            Jake Schreier     low-mid             3
# 3048           Dean Israelite     low-mid             3
# 3049            Timothy Hines         low             2
# 3050               Ciarán Foy     low-mid             3
# 3051             Dan Fogelman         low             2
# 3052      Angelina Jolie Pitt         low             2
# 3053               Ari Sandel     low-mid             3
# 3054             Henry Hobson         low             2
# 3055           Mark Neveldine         low             2
# 3056             Duke Johnson         low             2
# 3057            Rick Famuyiwa     low-mid             3
# 3058            Peter Sollett         low             2
# 3059       M. Night Shyamalan    high-mid             1
# 3060            Joel Edgerton    high-mid             1
# 3061            Joel Edgerton    high-mid             1
# 3062        John Erick Dowdle     low-mid             3
# 3063           Michael Polish         low             2
# 3064          Jeremy Saulnier         low             2
# 3065                Rob Cohen     low-mid             3
# 3066            Robert Eggers     low-mid             3
# 3067               David Gelb     low-mid             3
# 3068                 Jon Gunn         low             2
# 3069          Robert Fontaine         low             2
# 3070            Jerry Jameson         low             2
# 3071          Marielle Heller         low             2
# 3072               Jamal Hill         low             2
# 3073       Benjamin Dickinson         low             2
# 3074             Travis Cluff     low-mid             3
# 3075            Anthony Russo        high             0
# 3076              Zack Snyder        high             0
# 3077               Justin Lin        high             0
# 3078              David Yates        high             0
# 3079              David Yates        high             0
# 3080             Bryan Singer        high             0
# 3081               David Ayer        high             0
# 3082              James Bobin    high-mid             1
# 3083          Roland Emmerich        high             0
# 3084             Duncan Jones    high-mid             1
# 3085       Alessandro Carloni        high             0
# 3086                Paul Feig        high             0
# 3087                Paul Feig        high             0
# 3088              Alex Proyas     low-mid             3
# 3089               Dave Green    high-mid             1
# 3090    Cedric Nicolas-Troyan    high-mid             1
# 3091         Robert Schwentke    high-mid             1
# 3092               Jon M. Chu    high-mid             1
# 3093              Clay Kaytis        high             0
# 3094               Tim Miller        high             0
# 3095  Rawson Marshall Thurber        high             0
# 3096              Michael Bay    high-mid             1
# 3097              Ben Stiller     low-mid             3
# 3098                Gary Ross     low-mid             3
# 3099                James Wan        high             0
# 3100                Tim Story    high-mid             1
# 3101         Christian Ditter    high-mid             1
# 3102               J Blakeson     low-mid             3
# 3103         Nicholas Stoller    high-mid             1
# 3104              Ben Falcone    high-mid             1
# 3105              Burr Steers         low             2
# 3106             Jodie Foster     low-mid             3
# 3107           Gavin O'Connor         low             2
# 3108                Jon Lucas    high-mid             1
# 3109                Jon Lucas    high-mid             1
# 3110           Kevin Reynolds     low-mid             3
# 3111              Henry Joost     low-mid             3
# 3112            John Hillcoat         low             2
# 3113          Cyrus Nowrasteh         low             2
# 3114               Kirk Jones    high-mid             1
# 3115       Jaume Collet-Serra    high-mid             1
# 3116         Dan Trachtenberg    high-mid             1
# 3117            Peter Atencio     low-mid             3
# 3118          Patricia Riggen    high-mid             1
# 3119                Dan Mazer     low-mid             3
# 3120       William Brent Bell     low-mid             3
# 3121               Jason Zada     low-mid             3
# 3122             Harold Cronk     low-mid             3
# 3123           Michael Tiddes         low             2
# 3124           Bille Woodruff         low             2
# 3125        David F. Sandberg    high-mid             1
# 3126          Craig Gillespie     low-mid             3
#
# [3127 rows x 14 columns]

# %% [markdown]
# ## Evaluation
# ### Choosing Evaluation Metrics

# %% [markdown]
# For our dataset, accuracy is not the best evaluation metric, because that does not account properly for false positives. False positives for our business case are MUCH worse than a false negative. It would be very bad to predict that a movie will gross high, when in fact it grosses lowly. However, if we predict the movie will gross low, and it ends up grossing highly, that isn't as bad, because the director will either be pleasantly surprised, or he will choose to not undertake the filming in the first place. It is better to not film and miss out on the potential money, than to undertake the film thinking that it would be lucrative, when in fact it is not.
#
# Because we are using a multi-class classification model we can not simply use precision, recall, or f1 score, but must construct a cost matrix with different weights that correspond to the different combination of predictions and results. Below we have our cost matrix defined. As you can see we weight a false positive with a 20 and a false negative with a 6. We give them this much of a cost difference because of the aforementioned reasons about false positives. Any True predictions are a negative one, and the other numbers in the matrix are scaled appropriately dependent upon how bad they would be as a result.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc

cost_matrix = np.array([-1,10, 14,20,2,-1,10,14,4,2,-1,10,6,4,2,-1]) #give a reason for why these numbers chosen
cost_matrix = cost_matrix.reshape(4,4)
print(cost_matrix)
# Out:
# [[-1 10 14 20]
#  [ 2 -1 10 14]
#  [ 4  2 -1 10]
#  [ 6  4  2 -1]]

# %% [markdown]
# ### Dividing up training/testing data

# %% [markdown]
# For our dataset we want to use Stratified 10-fold cross validation because it is the best and works for our dataset well. Below we create the StratifiedKFold object and then use it many times later on in the lab. We selected this method instead of a simple 80/20 split because we new that we wanted to test on multiple randomized sets of data, instead of just the same one, so as to avoid data snooping and improper parameter tuning. We chose not to use the shuffle option becuase we wanted to compare our custom implementation and scikit-learn using the same indices for training and testing data. Below we also drop a few more fields that we no longer need due to categorizing the gross, etc.

# %%
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
cv = StratifiedKFold(n_splits=10)

drop_list = ['encoded_gross', 'gross_group', 
              'gross', 'director_name', 'actor_1_name', 'content_rating']
X = df.drop(drop_list, axis=1).values
y = df['encoded_gross'].values.astype(np.float) # x and y are now np.matrices 

X = StandardScaler().fit_transform(X)

df.drop(drop_list, axis=1)
# Out:
# array([[-0.58688608, -0.79211162, -0.55534186, ..., -0.49356338,
#         -6.2058806 ,  1.25902852],
#        [-0.98082676, -0.33320786, -0.65740598, ..., -0.26169983,
#         -6.09571558,  0.6856816 ],
#        [-1.14161887, -0.10375598, -0.65798726, ..., -0.24261767,
#         -5.87538554,  0.59012378],
#        ...,
#        [-1.21397533, -0.60855012, -0.6706798 , ..., -0.8994704 ,
#          1.39550579, -1.79882172],
#        [-0.03215328, -1.29690576, -0.59183531, ..., -0.90144982,
#          1.39550579,  0.49456596],
#        [ 0.12059923,  0.35514778, -0.50267453, ..., -0.4977945 ,
#          1.39550579,  0.39900814]])

# %% [markdown]
# # Modeling
# ### Create a combined wide and deep network to classify data with tensorflow

# %%
import tensorflow as tf
from tensorflow.contrib import learn
from tensorflow.contrib import layers
from tensorflow.contrib.learn.python import SKCompat
tf.logging.set_verbosity(tf.logging.WARN) # control the verbosity of tensor flow
